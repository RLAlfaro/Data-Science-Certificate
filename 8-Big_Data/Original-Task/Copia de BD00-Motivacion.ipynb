# %% [markdown]
# # Big Data
# # BD00 Motivacion

# %% [markdown]
# ## <font color='blue'>**Big Data**</font>
#
# Los influyentes de la industria, los académicos y otras partes interesadas prominentes ciertamente están de acuerdo en que Big Data se ha convertido en un gran cambio de juego en la mayoría, si no en todos, los tipos de industrias modernas en los últimos años. A medida que Big Data continúa impregnando nuestra vida cotidiana, ha habido un cambio significativo de enfoque de la exageración que lo rodea a encontrar un valor real en su uso.
#
# Si bien comprender y definir el valor de Big Data sigue siendo un desafío, otros desafíos prácticos, incluidos el financiamiento y el retorno de la inversión y las habilidades, continúan a la vanguardia para varias industrias diferentes que están adoptando Big Data. Dicho esto, según los informes de Investigación y Mercado, en 2017 el mercado global de Big Data valía  62.400  millones y para 2026 se espera que alcance los  733.600 millones.

# %% [markdown]
# Generalmente, la mayoría de las organizaciones tienen varios objetivos para adoptar proyectos de Big Data. Si bien el objetivo principal para la mayoría de las organizaciones es mejorar la experiencia del cliente, otros objetivos incluyen la reducción de costos, un marketing mejor dirigido y hacer que los procesos existentes sean más eficientes. En los últimos tiempos, las violaciones de datos también han hecho de la seguridad mejorada un objetivo importante que los proyectos de Big Data buscan incorporar.
#
# Sin embargo, lo que es más importante, ¿cuál es su posición en lo que respecta a Big Data? Es muy probable que descubra que está:
#
# 1. Intentando decidir si hay valor real en Big Data o no.
# 2. Evaluar el tamaño de la oportunidad de mercado.
# 3. Desarrollar nuevos servicios y productos que utilizarán Big Data.
# 5. Utilizando soluciones de Big Data. Reposicionar los servicios y productos existentes para utilizar Big Data, o
# 5. Ya utilizó soluciones de Big Data.

# %% [markdown]
# ### Roles
#
# 1. Arquitecto de datos
# 2. Arquitecto Big Data
# 3. Ingeniero de datos
# 4. Ingeniero MLOps
# 5. Cientifico de datos
# 6. Gobierno de datos y seguridad

# %% [markdown]
# ## <font color='blue'>**Las V de Big Data**</font>
# Las características más importantes del Big Data perfectamente se pueden clasificar en cuatro magnitudes, más conocidas como las cuatro V del Big Data, relativas a volumen, variedad, velocidad y veracidad. A estas cuatro V, podemos añadir tres más, como pueden ser la de Viabilidad y Visualización. Pero si hablamos de V en Big Data no podemos dejar pasar la principal característica del análisis de datos que es la V de Valor de los datos. Así pues, en los últimos artículos se empieza a hablar, ya no de las tradicionales cuatro V de Big Data, sino de las 7 “V” del Big Data:
#
# 1. Volumen
# 2. Velocidad
# 3. Variedad de los datos
# 4. Veracidad de los datos
# 5. Viabilidad
# 6. Visualización de los datos
# 7. Valor de los datos
#
#
#
# ### Volumen de información
#
# El volumen se refiere a la cantidad de datos que son generados cada segundo, minuto y días en nuestro entorno. Es la característica más asociada al Big Data, ya que hace referencia a las cantidades masivas de datos que se almacenan con la finalidad de procesar dicha información, transformando los datos en acciones.
#
# Cada vez estamos más conectados al mundo por lo que generamos más y más datos. Para algunas empresas, el estar en el mundo digital es algo obligatorio, por lo que la cantidad de datos generados es aún mayor. Por ejemplo, una empresa que vende sus productos únicamente a través de un canal online, le convendría implantar tecnología Big Data para procesar toda aquella información que recoge su página web rastreando todas las acciones que lleva a cabo el cliente; conocer donde cliquea más veces, cuántas veces ha pasado por el carrito de la compra, cuáles son los productos más vistos, las páginas más visitadas, etc.
#
# ![Volumen](https://drive.google.com/uc?export=view&id=1283Nnu0MnLHqWhQWvGk9S14xNqbJdb2d)

# %% [markdown]
# ### Velocidad de los datos
#
# La velocidad se refiere a los datos en movimiento por las constantes interconexiones que realizamos, es decir, a la rapidez en la que son creados, almacenados y procesados en tiempo real.
#
# Para los procesos en los que el tiempo resulta fundamental, tales como la detección de fraude en una transacción bancaria o la monitorización de un evento en redes sociales, estos tipos de datos deben estudiarse en tiempo real para que resulten útiles para el negocio y se consigan conclusiones efectivas.
#
# ![Velocidad](https://drive.google.com/uc?export=view&id=1N0L_erAkrW-LWNi_5yJBFOPz9YXarRnX)

# %% [markdown]
# ### Variedad de datos
#
# La variedad se refiere a las formas, tipos y fuentes en las que se registran los datos. Estos datos pueden ser datos estructurados y fáciles de gestionar como son las bases de datos,  o datos no estructurados, entre los que se incluyen documentos de texto, correos electrónicos, datos de sensores, audios, vídeos o imágenes que tenemos en nuestro dispositivo móvil, hasta publicaciones en nuestros perfiles de redes sociales, artículos que leemos en blogs, las secuencias de click que hacemos en una misma página, formularios de registro e infinidad de acciones más que realizamos desde nuestro Smartphone, Tablet y ordenador.
#
# Estos últimos datos requieren de una herramienta específica, debido a que el tratamiento de la información es totalmente diferente con respecto a los datos estructurados. Para ello, las empresas necesitan integrar, observar y procesar datos que son recogidos a través de múltiples fuentes de información con herramientas cualificadas.
#
# ![Variedad](https://drive.google.com/uc?export=view&id=1SGsqXEVEoJBjydJ7HY0DXSGDbZFqWFpk)

# %% [markdown]
# ### Veracidad de los datos
#
# Veracidad de los datos
# Cuando hablamos de veracidad nos referimos a la incertidumbre de los datos, es decir, al grado de fiabilidad de la información recibida.
#
# Es necesario invertir tiempo para conseguir datos de calidad, aplicando soluciones y métodos que puedan eliminar datos imprevisibles que puedan surgir como datos económicos, comportamientos de los consumidores que puedan influir en las decisiones de compra.
#
# La necesidad de explorar y planificar la incertidumbre es un reto para el Big Data que está a la orden del día en las compañías dedicadas al análisis de datos.
#
# ![Veracidad](https://drive.google.com/uc?export=view&id=1SQQAipzNhlJZGH5Wc8tiihMSg_QGDYaH)

# %% [markdown]
# ### Viabilidad
#
# La inteligencia empresarial es un componente fundamental para la viabilidad de un proyecto y el éxito empresarial. Se trata de la capacidad que tienen las compañías en generar un uso eficaz del gran volumen de datos que manejan.
#
# La inteligencia competitiva también se asocia con la innovación de los equipos de trabajo y el uso de tecnologías empleadas. Una empresa inteligente analiza, selecciona y monitoriza la información con el fin de conocer mejor el mercado en el que opera, a sus clientes y diseñar estrategias eficaces.
#
# Es necesario filtrar a través de esta información y seleccionar cuidadosamente los atributos y factores que son capaces de predecir los resultados que más interesan a las empresas. El secreto del éxito es descubrir las relaciones entre las variables ocultas.
#
# Una vez que conoces la viabilidad de tu organización, es el momento de detallar el proyecto en una hoja de ruta, y desarrollar el plan de negocio.
#
# ![Viabilidad](https://drive.google.com/uc?export=view&id=1EC5eN1gkKr1kXhxiIph5N-RzZHVG28YI)

# %% [markdown]
# ### Visualización de los datos
#
# Cuando hablamos de visualización nos referimos al modo en el que los datos son presentados. Una vez que los datos son procesados (los datos están en tablas y hojas de cálculo), necesitamos representarlos visualmente de manera que sean legibles y accesibles, para encontrar patrones y claves ocultas en el tema a investigar. Para que los datos sean comprendidos existen herramientas de visualización que te ayudarán a comprender los datos gráficamente y en perspectiva contextual.
#
# ![Viabilidad](https://drive.google.com/uc?export=view&id=14T4NHkXNZZd-4qgusy62o33XjD-1Q7J7)

# %% [markdown]
# ### Valor de los datos
# El dato no es valor. Tampoco tienes valor por el mero hecho de recopilar gran cantidad de información. El valor se obtiene de datos que se transforman en información; esta a su vez se convierte en conocimiento, y este en acción o en decisión. El valor de los datos está en que sean accionables, es decir, que los responsable de la empresas puedan tomar una decisión (la mejor decisión) en base a estos datos.
#
# No todos los datos de los que partimos se convierten en acción o decisión. Para ello, es necesario tener tecnologías aplicadas. Por ejemplo, una publicación en una red social, que gracias al uso de tecnologías de procesamiento de lenguaje natural, puede medir el sentimiento positivo o negativo, con la ayuda de un algoritmo de análisis de redes sociales o herramientas que permitan obtener de esto información.
#
# ![Viabilidad](https://drive.google.com/uc?export=view&id=142KM_5k5nCN6bWXQQBFE2F_RYSNW3q11)

# %% [markdown]
# ## La Historia de Big Data

# %% [markdown]
# ## <font color='blue'>**Aplicaciones**</font>
#
# Con esto en mente, tener una visión general de Big Data y su aplicación en diferentes industrias lo ayudará a apreciar mejor cuál es su función o cuál es probable que sea en el futuro, en su industria o en varias industrias.
#
# Comparación de caracteristicas  por industria
#
# ![Comparisons](https://drive.google.com/uc?export=view&id=1uFYgGxUtUulKVUEmqLf3ayfPnYyH-oQX)

# %% [markdown]
# ### Banca y valores
#
# Desafíos de Big Data específicos de la industria
# Un estudio de 16 proyectos en los 10 principales bancos minoristas y de inversión muestra que los desafíos en esta industria incluyen: alerta temprana de fraude de valores, análisis de ticks, detección de fraude de tarjetas, archivo de pistas de auditoría, informes de riesgo crediticio empresarial, visibilidad comercial, transformación de datos de clientes análisis social para el comercio, análisis de operaciones de TI y análisis de cumplimiento de políticas de TI, entre otros.
#
# Aplicaciones de Big Data en la industria bancaria y de valores
# La Securities Exchange Commission (SEC) está utilizando Big Data para monitorear la actividad del mercado financiero. Actualmente están utilizando análisis de red y procesadores de lenguaje natural para detectar la actividad comercial ilegal en los mercados financieros.
#
# Los comerciantes minoristas, los grandes bancos, los fondos de cobertura y otros llamados 'grandes' en los mercados financieros utilizan Big Data para el análisis comercial utilizado en el comercio de alta frecuencia, análisis de apoyo a las decisiones previas al comercio, medición de sentimientos, análisis predictivo, etc.
#
# Esta industria también depende en gran medida de Big Data para el análisis de riesgos, que incluyen; lucha contra el blanqueo de capitales, gestión de riesgos empresariales de la demanda, "conozca a su cliente" y mitigación del fraude.

# %% [markdown]
# ### Comunicaciones, medios y entretenimiento
#
# Desafíos de Big Data específicos de la industria
# Dado que los consumidores esperan rich media on-demand en diferentes formatos y una variedad de dispositivos, algunos desafíos de Big Data en la industria de las comunicaciones, los medios y el entretenimiento incluyen:
#
# Recopilar, analizar y utilizar los conocimientos de los consumidores
# Aprovechamiento del contenido de redes sociales y móviles
# Comprender los patrones de uso de contenido multimedia en tiempo real
#
# Aplicaciones de Big Data en la industria de las comunicaciones, los medios y el entretenimiento Las organizaciones de esta industria analizan simultáneamente los datos de los clientes junto con los datos de comportamiento para crear perfiles de clientes detallados que se pueden utilizar para:
#
# Crea contenido para diferentes audiencias objetivo Recomendar contenido a pedido
# Medir el rendimiento del contenido Un ejemplo de ello es el Campeonato de Wimbledon (vídeo de YouTube) que aprovecha Big Data para ofrecer un análisis detallado del sentimiento sobre los partidos de tenis a los usuarios de televisión, dispositivos móviles y la web en tiempo real.
#
# Spotify, un servicio de música a pedido, utiliza el análisis de Big Data de Hadoop para recopilar datos de sus millones de usuarios en todo el mundo y luego usa los datos analizados para brindar recomendaciones musicales informadas a usuarios individuales.
#
# Amazon Prime, que tiene como objetivo brindar una excelente experiencia al cliente al ofrecer videos, música y libros Kindle en una ventanilla única, también utiliza en gran medida Big Data.

# %% [markdown]
# ### Proveedores de servicios de salud
#
# Desafíos de Big Data específicos de la industria El sector de la salud tiene acceso a grandes cantidades de datos, pero se ha visto afectado por fallas en la utilización de los datos para frenar el costo del aumento de la atención médica y por sistemas ineficientes que sofocan los beneficios de atención médica más rápidos y mejores en todos los ámbitos.
#
# Esto se debe principalmente a que los datos electrónicos no están disponibles, son inadecuados o inutilizables. Además, las bases de datos de atención médica que contienen información relacionada con la salud han dificultado la vinculación de datos que pueden mostrar patrones útiles en el campo médico.
#
# ![Comparisons](https://drive.google.com/uc?export=view&id=1XfYLpp544LtxlDQ0giqm_d3iltbVpdWm)
#
#
#
# Aplicaciones de Big Data en el sector sanitario
#
# Algunos hospitales, como Beth Israel, están utilizando datos recopilados de una aplicación de teléfono celular, de millones de pacientes, para permitir que los médicos utilicen la medicina basada en evidencia en lugar de administrar varias pruebas médicas / de laboratorio a todos los pacientes que van al hospital. Una batería de pruebas puede ser effectiva, pero también puede ser costosa y, por lo general, ineficiente.
#
# La Universidad de Florida ha utilizado datos gratuitos de salud pública y Google Maps para crear datos visuales que permitan una identificación más rápida y un análisis eficiente de la información de atención médica, que se utiliza para rastrear la propagación de enfermedades crónicas.

# %% [markdown]
# ### Educación
# Desafíos de Big Data específicos de la industria
# Desde un punto de vista técnico, un desafío significativo en la industria de la educación es incorporar Big Data de diferentes fuentes y proveedores y utilizarlo en plataformas que no fueron diseñadas para los datos variables.
#
# Desde un punto de vista práctico, el personal y las instituciones deben aprender nuevas herramientas de análisis y gestión de datos.
#
# En el aspecto técnico, existen desafíos para integrar datos de diferentes fuentes en diferentes plataformas y de diferentes proveedores que no fueron diseñados para trabajar entre sí.
#
# Políticamente, los problemas de privacidad y protección de datos personales asociados con Big Data utilizados con fines educativos son un desafío.
#
# Aplicaciones de Big Data en la educación
#
# Los macrodatos se utilizan de forma bastante significativa en la educación superior. Por ejemplo, la Universidad de Tasmania. Una universidad australiana con más de 26000 estudiantes ha implementado un sistema de gestión y aprendizaje que rastrea, entre otras cosas, cuando un estudiante inicia sesión en el sistema, cuánto tiempo pasa en diferentes páginas del sistema, así como el progreso general de un estudiante. tiempo extraordinario.
#
# En un caso de uso diferente del uso de Big Data en la educación, también se utiliza para medir la efectividad del profesor para garantizar una experiencia agradable tanto para los estudiantes como para los profesores. El desempeño del maestro se puede ajustar y medir en función del número de estudiantes, la materia, la demografía de los estudiantes, las aspiraciones de los estudiantes, la clasificación de comportamiento y varias otras variables.
#
# A nivel gubernamental, la Oficina de Tecnología Educativa del Departamento de Educación de EE. UU. Está utilizando Big Data para desarrollar análisis que ayuden a corregir a los estudiantes del curso que se desvían al usar cursos de Big Data en línea. Los patrones de clic también se utilizan para detectar el aburrimiento.

# %% [markdown]
# ### Manufactura y recursos naturales
# Desafíos de Big Data específicos de la industria
# La creciente demanda de recursos naturales, incluidos el petróleo, los productos agrícolas, los minerales, el gas, los metales, etc., ha provocado un aumento del volumen, la complejidad y la velocidad de los datos que es un desafío de manejar.
#
# Del mismo modo, se encuentran sin explotar grandes volúmenes de datos de la industria manufacturera. La subutilización de esta información impide la mejora de la calidad de los productos, la eficiencia energética, la confiabilidad y mejores márgenes de ganancia.
#
# Aplicaciones de Big Data en Manufactura y Recursos Naturales
# En la industria de los recursos naturales, Big Data permite el modelado predictivo para respaldar la toma de decisiones que se ha utilizado para ingerir e integrar grandes cantidades de datos de datos geoespaciales, datos gráficos, texto y datos temporales. Las áreas de interés en las que se ha utilizado incluyen; interpretación sísmica y caracterización de yacimientos.
#
# Los macrodatos también se han utilizado para resolver los desafíos de fabricación actuales y para obtener una ventaja competitiva, entre otros beneficios.
#
# En el gráfico a continuación, un estudio de Deloitte muestra el uso de las capacidades de la cadena de suministro de Big Data actualmente en uso y su uso esperado en el futuro.
#
# ![Manufactura](https://drive.google.com/uc?export=view&id=1Z91myIbRrQ9VDjXomvFkx7R90icObw43)

# %% [markdown]
# ### Transporte
#
# Desafíos de Big Data específicos de la industria
# En los últimos tiempos, grandes cantidades de datos de las redes sociales basadas en la ubicación y los datos de alta velocidad de las telecomunicaciones han afectado el comportamiento de los viajes. Lamentablemente, la investigación para comprender el comportamiento de los viajes no ha progresado tan rápidamente.
#
# En la mayoría de los lugares, los modelos de demanda de transporte todavía se basan en nuevas estructuras de redes sociales poco conocidas.
#
# Aplicaciones de Big Data en la industria del transporte
# Algunas aplicaciones de Big Data por parte de gobiernos, organizaciones privadas e individuos incluyen:
#
# Uso de Big Data por parte de los gobiernos: control de tráfico, planificación de rutas, sistemas de transporte inteligentes, gestión de la congestión (mediante la predicción de las condiciones del tráfico)
# Uso de Big Data por parte del sector privado en el transporte: gestión de ingresos, mejoras tecnológicas, logística y ventaja competitiva (consolidando envíos y optimizando el movimiento de mercancías)
# El uso individual de Big Data incluye la planificación de rutas para ahorrar combustible y tiempo, para organizar viajes en turismo, etc.

# %% [markdown]
# ### Energía y servicios Públicos
#
# Desafíos de Big Data específicos de la industria
# La siguiente imagen muestra algunos de los principales desafíos en la industria de la energía y los servicios públicos.
#
# Aplicaciones de Big Data en la industria de la energía y los servicios públicos
# Los lectores de contadores inteligentes permiten recopilar datos casi cada 15 minutos en lugar de una vez al día con los lectores de contadores antiguos. Estos datos granulares se utilizan para analizar mejor el consumo de servicios públicos, lo que permite una mejor retroalimentación de los clientes y un mejor control del uso de los servicios públicos.
#
# En las empresas de servicios públicos, el uso de Big Data también permite una mejor gestión de los activos y la fuerza laboral, lo que es útil para reconocer errores y corregirlos lo antes posible antes de que se experimente una falla total.

# %% [markdown]
# ## <font color='blue'>**La historia**</font>
#
# el Censo de los Estados Unidos de 1880 tomó ocho años para tabular y se estimó que el censo de 1890 tardaría más de 10 años utilizando los métodos entonces disponibles.  Sin ningún avance en la metodología, la tabulación no habría sido completa antes de que el censo de 1900 tuviera que ser tomado.
#
#
# ![Senso](https://drive.google.com/uc?export=view&id=1F_5-EaHvFoua34HzhS_vhB38vLb95pju)
#
# La afluencia de datos del censo llevó a la invención de la máquina de tabulación de Hollerith (tarjetas perforadas), que "domesticó" los datos grandes y los dejó terminar el trabajo en aproximadamente un año.
#
# La maquina tenia un lector de tarjetas, un contador, un clasificador y un tabulador creado por el mismo.
#
# Hollerith observó que la mayor parte de las preguntas contenidas en los censos se podían contestar con opciones binarias: SÍ o NO, abierto o cerrado. Entonces ideó una tarjeta perforada, una cartulina compuesta por 80 columnas con 2 posiciones, con la cual se contestaba este tipo de preguntas.
#
#
# ![Senso](https://drive.google.com/uc?export=view&id=17VBy-QQVEk1d3O0Nv7uvGEhnc1PzbHKV)
#
#
# En 1932 La sobrecarga de datos continuó con el auge de la población estadounidense, la emisión de números de seguridad social, exigían un registro más completo y organizado.
#
# ![SeguridadSocial](https://drive.google.com/uc?export=view&id=1fVm_mE2wY5-XlpDPDQa0WBlKXBQON2sQ)

# %% [markdown]
# La primera  advertencia sobre el crecimiento del conocimiento como un problema de almacenamiento y recuperación llegó en 1944, cuando Fremont Rider, bibliotecario de la Universidad Wesleyana, estimó que las bibliotecas universitarias estadounidenses estaban duplicando su tamaño cada dieciséis años. Dada esta tasa de crecimiento, Rider estimó que la Biblioteca de Yale en 2040 tendría "aproximadamente 200 millones de volúmenes, que ocuparán más de 6.000 millas de estanterías requiriendo un personal de catalogación de más de seis mil personas.
#
# ![Biblioteca](https://drive.google.com/uc?export=view&id=1IoSv51a13rmLkgZcXMed6KTtzPFUUdT0)
#
# A principios de los años sesenta, se  observó que la gran cantidad de investigación científica era demasiado para que los seres humanos se mantuvieran al tanto. Las revistas abstractas, que se crearon a finales del siglo XIX como una forma de gestionar la creciente base de conocimientos, también estaban creciendo en la misma trayectoria (multiplicándose por un factor de diez cada medio siglo) y ya habían alcanzado una "magnitud crítica".
#
#
# ![Ciencia](https://drive.google.com/uc?export=view&id=1Y12r5EjFB9XH8l-QioKDz6j7yhc3IEGx)

# %% [markdown]
# En 1970, Edgar F. Codd, un matemático de Oxford que trabajaba en el Laboratorio de Investigación de IBM, publicó un artículo que mostraba cómo se podía acceder a datos almacenados en grandes bases de datos sin saber cómo se estructuró la información o dónde residía en la base de datos.
#
# ![DataBase](https://drive.google.com/uc?export=view&id=19oNQB-oBvLWM5KIhLFl5QE4OcY0sv3RT)
#
#
# En 1989, Howard Dresner expandió el término de "Business Intelligence(BI)", originalmente acuñado por Hans Peter Luhn en 1958. Dresner lo definió como "conceptos y métodos para mejorar la toma de decisiones empresariales usando sistemas de apoyo basados en hechos" .
#
# ![BussinessIntelligence](https://drive.google.com/uc?export=view&id=1SeX9Gf9snUED9JL2xGW3bgJeUmZUd0YB)
#
# En los 90 la aparición de la Internet y el aumento en la Capacidad de computo, se comenzaron a rediseñar los productos de la época.
#
#
# En 1997 el término “Big Data" fue utilizado por primera vez en un artículo de los investigadores de la NASA Michael Cox y David Ellsworth. Ellos  afirmaron que el aumento de los datos se estaba convirtiendo en un problema para los sistemas informáticos actuales. Esto también fue conocido como el "problema de los grandes datos".
#
# El término "Internet de las Cosas" fue acuñado por el empresario británico Kevin Ashton. "Si tuviéramos computadoras que supieran todo lo que hay que saber sobre las cosas -utilizando datos que recopilaron sin ninguna ayuda de nosotros- podríamos rastrear y contar todo, y reducir en gran medida los desperdicios,  pérdidas y el costo".
#
# En el 2002 un analista de Gartner, Doug Laney, publicó un trabajo de investigación titulado 3D Data Management: Control de Volumen de Datos, Velocidad y Variedad.
#
# ![BussinessIntelligence](https://drive.google.com/uc?export=view&id=1CfN8LfKIKvYMcRARKHsGl_wLERzouhGh)
#
# Hadoop fue creado en 2006 por la necesidad de nuevos sistemas para manejar la explosión de datos de la web. Hadoop es una forma 100% open source de almacenar y procesar datos que "permite el procesamiento paralelo distribuido de grandes cantidades de datos a través de servidores económicos y estándar que almacenan y procesan los datos y puede escalar sin límites ".
#
# MongoDB (del inglés humongous, "enorme") es un sistema de base de datos NoSQL, orientado a documentos y de código abierto. En lugar de guardar los datos en tablas, tal y como se hace en las bases de datos relacionales, MongoDB guarda estructuras de datos BSON (una especificación similar a JSON) con un esquema dinámico, haciendo que la integración de los datos en ciertas aplicaciones sea más fácil y rápida.
#
# Apache Kafka es un proyecto de intermediación de mensajes de código abierto desarrollado por LinkedIn y donado a la Apache Software Foundation escrito en Java y Scala. El proyecto tiene como objetivo proporcionar una plataforma unificada, de alto rendimiento y de baja latencia para la manipulación en tiempo real de fuentes de datos. Puede verse como una cola de mensajes, bajo el patrón publicación-suscripción, masivamente escalable concebida como un registro de transacciones distribuidas,1​ lo que la vuelve atractiva para las infraestructuras de aplicaciones empresariales.
#
# Apache Spark es un framework de computación en clúster open-source. Fue desarrollada originariamente en la Universidad de California, en el AMPLab de Berkeley. El código base del proyecto Spark fue donado más tarde a la Apache Software Foundation que se encarga de su mantenimiento desde entonces. Spark proporciona una interfaz para la programación de clusters completos con Paralelismo de Datos implícito y tolerancia a fallos.

# %% [markdown]
# ## <font color='blue'>**Arquitecturas Bigdata**</font>
#
#
# ![BussinessIntelligence](https://drive.google.com/uc?export=view&id=1TBJwoWSjukYmf3WflpRdC7uTumPQqnqY)
#
#
# La arquitectura Lambda es una arquitectura de procesamiento de datos diseñada para manejar cantidades masivas de datos aprovechando los métodos de procesamiento por lotes y de streaming. Este enfoque de la arquitectura intenta equilibrar la latencia, el rendimiento y la tolerancia a fallas mediante el uso del procesamiento por lotes para proporcionar vistas completas y precisas de los datos, al mismo tiempo que utiliza el procesamiento de streaming  para proporcionar vistas de datos en línea. Las dos salidas de vista se pueden unir antes de la presentación. El auge de la arquitectura lambda se correlaciona con el crecimiento de big data, análisis en tiempo real y el impulso para mitigar las latencias de map-reduce.
#
#
#
# ![NosSQL](https://drive.google.com/uc?export=view&id=1JI-PnbUFLu2wXpXNZp0J6Iw6krd2FRID)
#
# Nathan Marz creador de apache Storm, postuló la manera de bypasear el teorema CAP. La arquitectura Lambda dice que tengo que tener a Hadoop y además Storm e implementar todo en ambos lugares y mantenerlos sincronizados.
#
# ![NosSQL](https://drive.google.com/uc?export=view&id=1MA81Z3XEcHSgv8PwTYrgDOdVWNkWhwxp)
#
#
# La arquitectura Kappa es una arquitectura de software que se utiliza para procesar datos de transmisión. La premisa principal detrás de la arquitectura Kappa es que puede realizar tanto procesamiento en tiempo real como por lotes, especialmente para análisis, con un solo stack tecnologico. Se basa en una arquitectura de transmisión en la que una serie de datos entrantes se almacena primero en un motor de mensajería como Apache Kafka. A partir de ahí, un motor de procesamiento de flujo leerá los datos y los transformará en un formato analizable, y luego los almacenará en una base de datos de análisis para que los usuarios finales consulten.
#
# No somos los únicos en señalar que los sistemas de transmisión de datos están llegando a un punto de madurez que hace que los sistemas de lotes y arquitecturas más antiguos se vean menos atractivos ", escribe Tzoumas. "Pero ya está muerto por lotes? No del todo, es solo que la transmisión es un superconjunto apropiado de lotes, y los lotes pueden servirse igualmente bien, si no mejor, con una nueva generación de motores de transmisión modernos.
#
# ![NosSQL](https://drive.google.com/uc?export=view&id=1c6L6OSqmCYigtOqbMia-Fp6XFM93Vz6V)
