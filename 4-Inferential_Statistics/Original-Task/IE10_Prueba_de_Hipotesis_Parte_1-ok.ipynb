# %% [markdown]
# # Introducción a la inferencia estadística
# # IE10 Prueba de Hipótesis - Parte 1

# %% [markdown]
# ## <font color='blue'>**Definiciones**</font>
#
# Una hipótesis estadística es una afirmación o proposición respecto a alguna característica de una población, generalmente fundamentada sobre un parámetro de la misma. Contrastar una hipótesis es comparar las predicciones con la realidad que observamos ocurrida en una muestra. Si dentro del margen de error que estamos dispuestos a admitir, hay coincidencia, aceptaremos la hipótesis y en caso contrario la rechazaremos.
#
# 1. La hipótesis emitida se suele designar por $𝑯_𝟎$ y se llama **Hipótesis nula**. Lo de “nula” viene de que partimos del supuesto de que las diferencias entre el valor verdadero del parámetro y su valor hipotético, en realidad no son tales sino debidas al azar, es decir, no hay diferencia, o dicho de otra forma la diferencia es nula.
#
# 2. La hipótesis contraria se designa por $𝑯_𝟏$  y se llama **Hipótesis alternativa**.

# %% [markdown]
# ### Hipotesis nula
#
# La hipótesis nula (denotada por $H_0$) es la afirmación de que el valor de un parámetro de la población (media, proporción o desviación estándar) es igual a un valor aseverado.
#
# Las siguientes son hipótesis nulas típicas:
#
# 1. $H_0: \mu = 37$
# 2. $H_0: p = 0.5$
# 2. $H_0: \sigma = 15$
#
# La hipótesis nulas se aprueba en forma directa, en el sentido de que **se supone que es verdadera**, y llegamos a una conclusión de rechazar $H_0$ o no rechazar $H_0$.
#
# ### Hipotesis alternativa
#
# La hipótesis alternativa (denotada por $H_1$) es la afirmación de que el parámetro tiene un valor que difiere de la hipótesis nula. Los símbolos que emplea la hipótesis alternativa son: $\lt$, $\gt$ o bien $\ne$.
#
# ![Matriz Covarianza](https://drive.google.com/uc?export=view&id=1ZKsYo3RhWZ5jckX0Zc6YkSeeGW8O9tkz)
#
# Si está realizando un estudio y desea emplear una prueba de hipótesis para sustentar una aseveración, esta debe redactarse de tal manera que se convierta en la hipótesis alternativa. Esto quiere decir, que su aseveración debe expresarse utilizando solo estos símbolos $\lt$, $\gt$ o bien $\ne$.

# %% [markdown]
# ### Ejemplos
#
# 1. Sospechamos que las bolsas de frutos secos de 100 gramos, realmente no pesan 100 gramos. Para contrastar esta hipótesis plantearíamos:
#
# $$H_0: \mu = 100$$
# $$H_1: \mu \neq 100$$
#
# 2. Pensamos que la proporción de gente que votó al partido A en las elecciones (35%) ahora es inferior ya que no lo han hecho muy bien. Para contrastar esta hipótesis:
#
# $$H_0:p \geq 0.35 $$
# $$H_1:p < 0.35 $$
#
# 3. Estaría contento de comprobar que no pueden demostrar que mi media de notas ha bajado de 6.2 como parecen indicar los últimos exámenes. Para contrastar esta hipótesis:
#
# $$H_0:\mu \leq 6.2 $$
# $$H_1:\mu > 6.2 $$
#
# ### Contraste de hipótesis
# Se formula la hipótesis sobre la población (ej. $\mu$, $p$, $\sigma$, etc.).  Entonces las conclusiones sobre la validez de la hipótesis se basarán en la información de una muestra (ej. $\bar{x}$, $\hat{p}$, $S$, etc).
#
# La realización de un contraste de hipótesis __no consiste en__ decidir cuál de las dos hipótesis ($H_0$ o $H_1$) es más creible, sino en decidir si la muestra proporciona o no suficiente evidencia para descartar $H_0$. Mientras no tengamos suficiente evidencia para aceptar $H_1$ tendremos que creernos que $H_0$ es cierta.

# %% [markdown]
# ## <font color='green'>**Actividad 1**</font>
#
# Siguiendo los ejemplos anteriores, defina tres ejemplos de hipotesis identificando $H_0$ y $H_1$.

# %% [markdown]
# Ejemplo #1.
# La rentabilidad promedio de un activo financiero creemos que no es superior al 2% prometido
#
# $$H_0:\mu \geq 2.0 $$
# $$H_1:\mu < 2.0 $$
#
# Ejemplo #2.
# La proporción de objetos defectuosos en una cadena de producción creemos que es menor al 5%.
#
# $$H_0:p \geq 0.05 $$
# $$H_1:p < 0.05 $$
#
# Ejemplo #3. Sospechamos que una maquina industrial ha presentado un desperfecto y que el contenido liquido de una caja de leche es distinto a los 200 ml estipulado inicialmente
#
# $$H_0:\mu = 200 $$
# $$H_1:\mu \neq 200 $$

# %% [markdown]
# <font color='green'>Fin Actividad 1</font>

# %% [markdown]
# ## <font color='blue'>**Estadístico de prueba**</font>
# El **estadístico de prueba**, es un valor que se utiliza para tomar la decisión sobre la hipótesis nula y se calcula convirtiendo el **estadístico muestral** (tales como la media muestral $\bar{x}$, o la proporción muestral $\hat{p}$) en una puntuación (tales como $Z$ o $t$), bajo el supuesto que la hipótesis nula es verdadera.
#
# ![Estadísticos de prueba](https://drive.google.com/uc?export=view&id=1rUkbc7E8yH0W9caOGtPmqA1rzEWtE4z4)
#
# ### Prueba $Z$
#
# La __prueba $Z$__, es un tipo de prueba paramétrica que se utiliza para determinar el grado de significatividad estadística de las diferencias entre las medias de dos conjuntos de datos. Se utiliza cuando las muestras son amplias (de más de 30 individuos aproximadamente) e independientes (esto es, no correlacionadas). Opera con la media, la desviación típica y el número de individuos de cada muestra. Una vez calculado el valor de $Z$, se comparará con el valor crítico de $Z$ obtenido de una curva de distribución normal. La hipótesis nula sostiene que la diferencia entre medias no es significativa y será rechazada si el valor obtenido en la prueba Z sobrepasa el valor crítico.
#
# El estadístico de __prueba $Z$__, es un valor que se utiliza para tomar la decisión sobre la hipótesis nula y se calcula convirtiendo el estadístico muestral (como la media muestral $\bar{x}$, proporción muestral $\hat{p}$) en una puntuación (como $Z$), bajo el supuesto que la hipótesis nula es verdadera. Este test considera que $\sigma$,  (Desviacion estándar) es conocida.
#
# Para determinar si se acepta o rechaza la hipótesis $H_0$, se define una valor de $Z$ crítico. Este valor puede ser sobre una cola o ambas colas como muestra la figura siguiente.
#
# <img alt="Region de rechazo" title="Region de rechazo" src="https://drive.google.com/uc?export=view&id=1jVrPzaSmszqzUv8RsbJV5PLh3QEWbDBF" width=850px>
#
#
# Las colas en una distribución corresponden a las regiones extremas, limitadas por los valores críticos:
#
# __Valores críticos para $\mu$ y $p$__
#
# <img alt="Valores críticos mu y p" title="Valores críticos mu y p" src="https://drive.google.com/uc?export=view&id=1Erl4W8RZhQmP-Akj3JNQWgJsvaRLpMlq" width=850px>
#
#
# En la siguiente imagen, se calcula el valor critico para distintos rangos de confianza, $\alpha= 10\%, 5\%, \dots$, etc., para el caso de una y dos colas.
# <img alt="Region de rechazo" title="Region de rechazo" src="https://drive.google.com/uc?export=view&id=1xD-AzO-LTRTjD2OIJGbWBHkqAs5zQ6SZ" width=850px>
#
# ### Valor-P o P-Value
# El __nivel crítio $P$__(o __Valor-$P$__), es el nivel de significación (1 - nivel de confianza) __más pequeño__ para el que la muestra obtenida obligaría a rechazar la hipótesis nula.
# * El Valor-P es la probabilidad (calculada bajo $H_0$) de obtener un resultado que sea menos compatible con $H_0$ que el resultado obtenido con la muestra.
# * El Valor-P depende de la muestra.
# * Puede considerarse como el apoyo que la hipótesis nula recibe de las observaciones de la muestra:
#  * Si el Valor-P e __menor__ que el nivel de significación ($\alpha$) prefijado, el apoyo a $H_0$ es escaso y, por tanto, $H_0$ debe rechazarse.
#  * Si el Valor-P es __mayor o igual__ que el nivel de significación ($\alpha$) prefijado, el apoyo a $H_0$ es suficiente y, por tanto, $H_0$ __NO__ debe rechazarse.
#
# El siguiente es el procedimiento para el cálculo de los Valores-P
#
# <img alt="Cálculo Valores P" title="Cálculo Valores P" src="https://drive.google.com/uc?export=view&id=1Yo_9C5G33I8AvdN3Ai6ceOQ8OYO-J7MM" width=850px>
#
# ### Criterios de decisión
# El procedimiento convencional de prueba de hipótesis requiere que __siempre probemos la hipótesis nula__, de manera que nuestra conclusión inicial siempre será una de las siguientes:
#
# 1. Rechazo la Hipótesis nula.
# 2. No rechazo la hipótesis nula.
#
# La decisión de rechazar o no una hipótesis nula, se puede realizar a través de dos métodos; el __Método clásico__ o por __Valor P__:
#
# __Método clásico__<br>
# * __Rechazo__ $H_0$  si el estadístico de prueba ($Z$ o $t$) cae dentro de la Región crítica.
#
# * __No Rechazo__ $H_0$  si el estadístico de prueba __NO__ cae dentro de la Región crítica.
#
# __Valor P__<br>
# * __Rechazo__ $H_0$  si el valor $P \le \alpha$, donde $\alpha$ es el nivel de significancia.
# * __No Rechazo__ $H_0$  si el valor $P \gt \alpha$
# <br><br>
#
# ### Entonces,  considerando el método clásico, rechazamos $H_0$ si ...
#
# <img alt="Rechazo H nula" title="Rechazo H nula" src="https://drive.google.com/uc?export=view&id=14BlLMoupsYjAFI73JXqzyu2pj6k3yude" width=850px>

# %% [markdown]
# ### Ejemplo: Hipótesis para la media  ($\sigma$ conocido)
#
# Una manada de 1.500 novillos fue alimentada con un grano especial rico en proteínas durante un mes. Se pesó una muestra aleatoria de 29 y habían ganado un promedio de 7.7 libras. Si la desviación estándar de la ganancia de peso para todo el rebaño es 7.1, pruebe la hipótesis de que la ganancia de peso promedio por novillo durante el mes fue de más de 5 libras.
#
# 1. Hipotesis nula, $H_0:\mu = 5$
# 2. Hipótesis alternativa, $H_1:\mu > 5$
#
# Vamos a calcular $Z$:
#
# $$Z = \frac{7.7 - 5}{\frac{7.1}{\sqrt{29}}} = 2.049$$
#
# Si pedimos un valor de 5% de significación, estonces si vamos a la primera tabla del diagrama vemos que para el 5% de significancia necesitamos un z de 1.645, por lo tanto como nuestro z es mayor que 1.645, se rechaza la hipotesis nula, con lo cual hubo ganancia de peso, estimada con 5% de significancia.

# %% [markdown]
# ## <font color='green'>**Actividad 2**</font>
# ### Hipótesis para la media  ($\sigma$ conocido)
#
# Se desea contrastar con un nivel de significación del 5 % la hipótesis de que “la talla media de los hombres de 18 o más años de un país es igual a 180”. Suponiendo que la desviación estándar de las tallas en la población es 4, contraste dicha hipótesis frente a la alternativa de que es distinta.
#
# Los datos constituyen una muestra de $n=15$ hombres seleccionados al azar, cuyas alturas son: 167, 167, 168, 168, 168, 169, 171, 172, 173, 175, 175, 175, 177, 182, 195.
#
# $𝑋$: Altura de los hombres mayores o igual a 18 años<br>
# $X \sim (\mu, 4)$
#
# 1. Calcular estadisticos muestra
# 2. Definir hipótesis
# 3. Definir tipo de prueba a aplicar
# 4. Calcular valor crítico o Z crítico
# 5. Calcule estadístico de prueba
# 6. Definir regla decisión
# 7. Calcular valor-p
# 8. Interprete y concluya
#
# Notas:
# - Desarróllelo manualmente
# - Impleméntelo en Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tu código aquí ...

# X = la talla media de los hombres de 18 años o más de un pais es igual a 180 (con un 5% de significancia)
# X∼(μ,4) 

import pandas as pd

alt_muestra = [167, 167, 168, 168, 168, 169, 171, 172, 173, 175, 175, 175, 177, 182, 195]
x = pd.Series(alt_muestra)

# 1. Calcular estadisticos muestra

Mu = x.describe()['mean']
Sig = 4
S   =  x.describe()['std']
n = x.describe()['count']
print(Mu, Sig, S, n)
# Out:
# 173.46666666666667 4 7.356888576280704 15.0

# %% [markdown]
# 2. Definir hipótesis
#
# $$ H_0 =  \mu = 180 cm $$
# $$ H_1 =  \mu \neq 180 cm $$
#
# 3. Definir tipo de prueba a aplicar
#
# Como se conoce la desviación estandar de la población, se utiliza la prueba Z.

# %%
from scipy import stats # importando scipy.stats
import numpy as np

# 4. Calcular valor crítico o Z crítico
alpha = 0.05
Zcritico = stats.norm.ppf(1-(alpha/2))
print(f'El valor de Zcritico es {Zcritico:2.4}')

# 5. Calcule estadístico de prueba
Z_test = (Mu - 180)/(Sig/np.sqrt(n))
print(f'El valor del estadistico de prueba es {Z_test:2.4}')
# Out:
# El valor de Zcritico es 1.96
# El valor del estadistico de prueba es -6.326

# %% [markdown]
# 6. Definir regla decisión
#
# No rechazo si =>
# $$ -1.96 <= Z_{test} <= 1.96 $$
#
# Rechazo si =>
# $$ Z_{test} > 1.96 $$
# $$ Z_{test} < -1.96 $$

# %%
stats.norm.cdf(Z_test)
# Out:
# 1.2590259277030688e-10

# %%
stats.norm.cdf(Zcritico)
# Out:
# 0.975

# %%
# 7. Calcular valor-p

pvalue = 1 - stats.norm.cdf(Z_test)
print(f'Valor-p: {pvalue*2:4.2f}') #2 colas
# Out:
# Valor-p: 2.00

# %% [markdown]
# 8. Interprete y concluya
#
# Se rechaza H_0 con 95% de significancia, en consecuencia se acepta H_1.
# Es decir, la talla media de los hombres de 18 años o más no es 180 cm.

# %% [markdown]
# <font color='green'>Fin Actividad 2</font>

# %% [markdown]
# ### **T-Test**
#
# __Test-T__ es una prueba en la que el estadístico utilizado tiene una distribución __t de Student__ si la hipótesis nula es cierta. Se aplica cuando la población estudiada sigue una distribución normal, pero el tamaño muestral es demasiado pequeño como para que el estadístico en el que está basada la inferencia esté normalmente distribuido, utilizándose una estimación de la desviación típica en lugar del valor real.
#
# Para calcular __t__ se utiliza la siguiente formula:
#
# $$ t = \frac{\bar{x} - \mu}{\frac{S}{\sqrt{n}}}$$
#
# Donde $S$ es la la desviacion estandar muestral _insesgada_.

# %% [markdown]
# ### Ejemplo: Hipótesis para la media  ($\sigma$ desconocido)
# ### Rentabilidad fondos de inversión
#
# Sea X la variable ”rentabilidad de cierto tipo de fondos de inversión tras una apreciación fuerte del marco con respecto al dólar”. Se considera que la media de esta variable es 15. Un economista afirma que dicha rentabilidad media ha variado, por lo que lleva a cabo un estudio en las condiciones reseñadas anteriormente, sobre una muestra de 9 fondos cuya media muestral resulta ser de 15,308 y cuya varianza muestral es 0,193.
#
# 1. Especificando las hipótesis necesarias, contrastar la afirmación del economista al 5%.
#
# 2. A partir del resultado de punto 1, razonar si el intervalo de confianza para la media al 95% contendrá o no al valor 15.

# %%
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import matplotlib.pyplot as plt #importando matplotlib

# 1.  calcular estadisticos muestra
xbar = 15.308
S2 = 0.193 # varianza muestral
S = np.sqrt(S2) # desv. std muestral insesgada (asumimos)
n = 9

print(f'Xbarra: {xbar:4.2f}')
print(f'S: {S:4.2f}')
print(f'Tamaño muestra: {n}')


# 2. Definir hipotesis a contrastar (prueba bilateral - 2 colas)
#    H0:   Mu = 15
#    H1:   Mu ≠ 15

# 3. como n < 30 y no se conoce Sigma, aplicaremos T Student
alpha = 0.05
mu = 15

# 4. calcular valor critico de T
#    n-1 grados de libertad, donde n corresponde al numero de la muestra y 2 colas
Tcritico = stats.t.ppf(1-(alpha/2), df=(n-1)) 
print(f'T critico: {Tcritico:4.2f}')


# 5. calcular Estadistico de prueba t
t =  (xbar - mu) / (S / np.sqrt(n))
print(f't: {t:4.2f}')

# 6. Define Regla de decision
#    no rechaza H0 si: -Tcritico <= t <= Tcritico
#    rechazar H0 si:  t < -Tcritico  o  t > Tcritico  


# 7. calcular valor-p
pvalue = 1 - (stats.t.cdf(t, df=(n - 1)))
print(f'Valor-p: {pvalue*2:4.2f}') #2 colas
# Out:
# Xbarra: 15.31
# S: 0.44
# Tamaño muestra: 9
# T critico: 2.31
# t: 2.10
# Valor-p: 0.07

# %% [markdown]
# Conclusión:
#
# Como $t$ de prueba se encuentra entre $+- Tcritico$ , no se rechaza la $H_0$. No existe evidencia para afirmar que la rentabilidad ha cambiado.
#
# Al observar el valor-p , este es mayor a $\alpha=0,05$. Por tanto no se rechaza $H_0$.

# %% [markdown]
# ## <font color='green'>Actividad 3</font>
# ### Control de calidad de los dulces M&M
#
# Se adjuntan los pesos de 13 dulces M&M rojos, elegidos de una bolsa que contiene 465 M&M. A continuación se presentan los pesos (en gramos), los cuales tienen una media $\bar{x} = 0,8635$ g y una desviación estándar de $𝑆=0,0576$ 𝑔. En el empaque se afirma que el peso neto del contenido es 396,9 g. de manera que los M&M deben tener un peso medio de al menos 396,9/465=0,8535 g. para dar la cantidad anunciada. Utilice los datos muestrales con un nivel de significancia de 0,05, para probar la aseveración que hizo un gerente de producción que los M&M tienen en realidad una media mayor que 0,8535 g. de manera que los consumidores están recibiendo más que la cantidad indicada en la etiqueta.
#
# dulces = (0.751, 0.841, 0.856, 0.799, 0.966, 0.859, 0.857, 0.942, 0.873, 0.809, 0.890, 0.878, 0.905)
#
# 1. Calcular estadísticos de muestra
# 2. Definamos la hipótesis a contrastar
# 3. Identificar el estadístico que nos ayudará a definir si la hipótesis del gerente es cierta.
# 4. Calcular el estadístico de prueba con los datos entregados en la muestra de 13 datos.
# 5. Calcular el valor crítico
# 6. Describa la regla de desición
# 7. Calcular el Valor-P
# 8. Interprete y concluya

# %%
# Tu código aquí ...

import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import matplotlib.pyplot as plt #importando matplotlib
import pandas as pd

dulces_list = [0.751, 0.841, 0.856, 0.799, 0.966, 0.859, 0.857, 0.942, 0.873, 0.809, 0.890, 0.878, 0.905]
x = pd.Series(dulces_list)
# print(x.describe()['mean'])

# 1.  calcular estadisticos muestra
xbar = x.describe()['mean']
S = x.describe()['std'] #np.sqrt(S2) # desv. std muestral insesgada (asumimos)
S2 = S**2 # varianza muestral
n = x.describe()['count']

print(10*'----')
print('\tEstadisticos de la muestra')
print(f'Xbarra: {xbar:4.4f}')
print(f'S: {S:4.4f}')
print(f'Tamaño muestra: {n}')
print(10*'----')

# 2. Definir hipotesis a contrastar (prueba UNILATERIAL - 1 cola izquierda)
#    H0:   Mu >= 0.8535
#    H1:   Mu <  0.8535

# 3. como n < 30 y no se conoce Sigma, aplicaremos T Student
alpha = 0.05
mu = 0.8535 #esta es la hipotesis del gerente

## hasta acá

# 4. calcular valor critico de T
#    n-1 grados de libertad, donde n corresponde al numero de la muestra y 1 cola
Tcritico = stats.t.ppf(1-(alpha), df=(n-1)) 
print(f'T critico: {Tcritico:4.2f}')

# 5. calcular Estadistico de prueba t
t =  (xbar - mu) / (S / np.sqrt(n))
print(f't: {t:4.2f}')

# 6. Define Regla de decision
#    no rechazar H0 si: t > Tcritico
#    rechazar H0 si: t <= Tcritico 

# 7. calcular valor-p
pvalue = 1 - (stats.t.cdf(t, df=(n - 1)))
print(f'Valor-p: {pvalue:4.2f}') #1 cola
# Out:
# ----------------------------------------
# 	Estadisticos de la muestra
# Xbarra: 0.8635
# S: 0.0576
# Tamaño muestra: 13.0
# ----------------------------------------
# T critico: 1.78
# t: 0.63
# Valor-p: 0.27

# %% [markdown]
# **_Conclusión:_** Se rechaza H_0 (por que t=0.63<1.78=T_critico), con un 95% de significancia no se puede afirmar que el contenido de una bolsa de M&M será mayor que 396.9 gramos.

# %% [markdown]
# <font color='green'>Fin Actividad 3</font>

# %% [markdown]
# ## <font color='green'>Actividad 4 (Opcional)</font>
# ### Experimento genético de Mendel
#
# Cuando Gregor Mendel realizó sus famosos experimentos de hibridación con guisantes, uno de ellos dio por resultado descendencia que consistía en 428 plantas de guisantes con vainas verdes y 152 plantas guisantes con vainas amarillas. Según la teoría de Mendel, $\frac{1}{4}$ de los vástagos de guisantes debían tener vainas amarillas. Utilice un nivel de significancia de un 5%, con el método tradicional y P, para probar la aseveración de que la proporción de vástagos de guisantes con vainas es igual a $\frac{1}{4}$.
# 1. Leer el enunciado y rescatar la información, y la hipótesis para desarrollar el análisis con el método tradicional.
# 2. Definir la hipótesis a contrastar
# 3. Identificar el estadístico que nos ayudará a definir si la hipótesis sobre la proporción de vainas amarillas.
# 4. Calcular el estadístico de prueba
# 5. Calcular el valor crítico
# 6. Interprete y concluya
# 7. Calcular el Valor-P

# %%
# 1. Leer el enunciado y rescatar la información, y la hipótesis para desarrollar el análisis con el método tradicional.
# X = proporción de vastagos de guisantes
# p = 1/4

# 2. Definir la hipótesis a contrastar
# H_0 : p = 1/4
# H_1 : p != 1/4

# 3. Identificar el estadístico que nos ayudará a definir si la hipótesis sobre la proporción de vainas amarillas.
# Utilizamos el estadistico Z

# 4. Calcular el estadístico de prueba
p = 1/4
n = (152+428)
p_tongo = 152/n
Z_test = (p_tongo - p)/np.sqrt(p*(1-p)/n)
print(f'El valor del estadistico de prueba es {Z_test:2.4}')

# 5. Calcular el valor crítico
alpha = 0.05
Zcritico = stats.norm.ppf(1-(alpha/2))
print(f'El valor de Zcritico es {Zcritico:2.4}')
# Out:
# El valor del estadistico de prueba es 0.6712
# El valor de Zcritico es 1.96

# %% [markdown]
# 6. Interprete y concluya
#
# No rechazo si =>
# $$ -1.96 <= Z_{test} <= 1.96 $$
#
# Rechazo si =>
# $$ Z_{test} > 1.96 $$
# $$ Z_{test} < -1.96 $$
#
#
# Dados los datos, se acepta H_0, por lo tanto la proporción de los vastagos de guisantes amarillos efectivamente es de 1/4

# %%
# 7. Calcular el Valor-P

pvalue = 1 - stats.norm.cdf(Z_test)
print(f'Valor-p: {pvalue*2:4.2f}') #2 colas
# Out:
# Valor-p: 0.50

# %% [markdown]
# <font color='green'>Fin Actividad 4</font>

# %% [markdown]
# ## <font color='blue'>**Errores Tipo I y II**</font>
#
# Cuando probamos la  hipótesis llegamos a la conclusión de rechazarla o no rechazarla. Tales conclusiones pueden ser correctas o incorrectas (incluso cuando se hace todo correctamente)ncia del contraste se acepta.
#
# Ninguna prueba de hipótesis es 100% cierta. Puesto que la prueba se basa en probabilidades, siempre existe la posibilidad de llegar a una conclusión incorrecta. Cuando se realiza una prueba de hipótesis, se puede cometer dos tipos de error: __tipo I__ y __tipo II__. Los riesgos de estos dos errores están inversamente relacionados y se determinan según el nivel de significancia y la potencia de la prueba. Por lo tanto, se debe determinar qué error tiene consecuencias más graves para su situación antes de definir los riesgos.
#
# ### Error de tipo I
# Si se rechaza la hipótesis nula __$H_0$__ cuando es verdadera, se comete un __error de tipo I__. La probabilidad de cometer un __error de tipo I__ es __$\alpha$__, que es el __nivel de significancia__ que se establece para la prueba de hipótesis. Un $\alpha = 0.05$ indica que se está dispuesto a aceptar una probabilidad de 5% de estar equivocado al rechazar la hipótesis nula. Para reducir este riesgo, se debe utilizar un valor menor para $\alpha$. Sin embargo, usar un valor menor para alfa significa que usted tendrá menos probabilidad de detectar una diferencia si esta realmente existe.
#
# ### Error de tipo II
# Cuando la hipótesis nula __$H_0$__ es falsa y no se la rechaza, se comete un __error de tipo II__. La probabilidad de cometer un error de __tipo II__ es __$\beta$__, la cual depende de la potencia de la prueba. Se reducir el riesgo de cometer un error de tipo II al asegurarse de que la prueba tenga suficiente potencia. Para ello, debemos asegurarnos de que el tamaño de la muestra sea lo suficientemente grande como para detectar una diferencia práctica cuando esta realmente exista.
#
# La probabilidad de rechazar la hipótesis nula cuando es falsa es igual a $1 - \beta$. Este valor es la __potencia de la prueba__.
#
# Verdad acerca de la población
#
# | Decisión basada <br> en la muestra | $H_0$ es verdadera | $H_0$ es falsa |
# |-------------------------------|:---------------:|:-----------:|
# | No rechazar $H_0$  | <font color='green'>__Decisión correcta__</font> <br>(probabilidad = $1-\alpha$)     |__Error tipo II__ <br> no rechazar $H_0$ cuando es falsa <br>(probabilidad = $\beta$) |
# | Rechazar $H_0$   | __Error tipo I__ <br>rechazar $H_0$ cuando es verdadera <br>(probabilidad = $\alpha$)  | <font color='green'>__Decisión correcta__</font> <br>(probabilidad = $1-\beta$)|
#
#
# ### Ejemplo de error de tipo I y tipo II
# Para entender la interrelación entre los errores de __tipo I__ y __tipo II__, y para determinar cuál error tiene consecuencias más graves para una situación específica, consideremos el siguiente ejemplo.
#
# Un investigador médico desea comparar la efectividad de dos medicamentos. Las hipótesis nula y alternativa son:
#
# Hipótesis nula ($H_0$): $\mu_1 = \mu_2$, los dos medicamentos tienen la misma eficacia.
#
# Hipótesis alternativa ($H_1$): $\mu_1 \ne \mu_2$, los dos medicamentos no tienen la misma eficacia.
#
# Un __error de tipo I__ se produce si el investigador rechaza la hipótesis nula y concluye que los dos medicamentos son diferentes cuando, en realidad, no lo son. Si los medicamentos tienen la misma eficacia, el investigador podría considerar que este error no es muy grave, porque de todos modos los pacientes se beneficiarían con el mismo nivel de eficacia independientemente del medicamento que tomen. Sin embargo, si se produce un __error de tipo II__, el investigador no rechaza la hipótesis nula cuando debe rechazarla. Es decir, el investigador concluye que los medicamentos son iguales cuando en realidad son diferentes. Este error puede poner en riesgo la vida de los pacientes si se pone en venta el medicamento menos efectivo en lugar del medicamento más efectivo.
#
# Cuando realice las pruebas de hipótesis, considere los riesgos de cometer errores de tipo I y tipo II. Si las consecuencias de cometer un tipo de error son más graves o costosas que cometer el otro tipo de error, entonces elija un nivel de significancia y una potencia para la prueba que reflejen la gravedad relativa de esas consecuencias.
