# %% [markdown]
# # Introducción a la inferencia estadística
# # IE08 Intervalos de confianza

# %%
# Importamos librerias 
import numpy as np 
from scipy import stats 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# ## <font color='blue'>**Distribuciones Muestrales**</font>
# ### Introducción
#
# Generalmente las __poblaciones__ son demasiado grandes como para ser estudiadas en su totalidad. Por esta razón es necesario seleccionar una __muestra__ representativa de un tamaño más manejable. Esta muestra se utiliza luego para sacar conclusiones sobre la población. Por ejemplo, se puede calcular la media muestral, el estadístico __$\bar{x}$__, y utilizarlo como un estimado de la media poblacional __$\mu$__. El __estadístico se utiliza como estimador del parámetro__. Al confiar en una muestra para sacar alguna conclusión o inferencia sobre la población, estamos aplicando la __estadística inferencial__.

# %% [markdown]
# ## <font color='blue'> Distribución de Medias Muestrales</font>
#
# La distribución muestral del $\bar{x}$ de tamaño muestral __$n$__, es la distribución que resulta cuando un experimento se lleva a cabo una y otra vez (siempre con tamaño muestral __$n$__) y obtenemos los distintos valores de $\bar{x}$. Esta distribución, describe la variabilidad de los promedios muestrales alrededor de la media poblacional $\mu$.
#
# <img src="https://drive.google.com/uc?export=view&id=1kjCCkX82IVNwgQqASnfOq5m1OXOd7RnP" width="800" align="left" title="Distribución medias muestrales"/>

# %% [markdown]
# Sea $X$ la variable aleatoria observada (de una población) cuya distribución es Normal
#
#
# $$X \rightarrow 𝑵(\mu, \sigma)$$
#
#
# Se verifica que el estadístico muestral $\bar{x}$ es también normal con la siguiente media y desviación standar:
#
#
# $$\bar{x} \rightarrow 𝑵(\mu , \frac{\sigma}{\sqrt{n}})$$
#
#
# La distribución de probabilidad de un estadístico se llama __Distribución Muestral__.
#
# <img src='https://drive.google.com/uc?export=view&id=1Aeqqyq-W8uJafQr1-zd_wEUtNRqs7NLH' width="600" align="left" style="margin-right: 20px">
# <br>

# %% [markdown]
# Cuando $n \rightarrow \infty$, se puede observar que la función de probabilidad se aproxima a la función de densidad de la distribución normal, con idéntica esperanza y varianza inversamente proporcional al tamaño muestral, $\bar{x} \rightarrow 𝑵(\mu , \frac{\sigma}{\sqrt{n}})$.
#
# Este comportamiento NO es casual, sino consecuencia del __Teorema del Límite Central__ (ver notebook __IE06__).
#
# <img src='https://drive.google.com/uc?export=view&id=1Cb77U7UnLa1jfTPehSYbw9tv4qPSXzQB' width="600" style="margin-right: 20px">
# <br>
# <br>
#
# __Nota2__:
# 1. Observe como en la distribución muestral afecta el $\sigma$ de las medias muestrales. Al estan dividido por $\sqrt{n}$ (tamaño de la muestra) le da la forma caractarística a la distribución.
# 2. Esta desviación estándar de las medias muestrales no debemos confundirla con la desviación estándar de una muestra ($s$), ni mucho menos con la desviación estándar de la población ($\sigma$).

# %% [markdown]
# ### Casos de uso de la Distribución Muestral
#
# Existen muchas decisiones que se toman con base en los resultados muestrales. Por ejemplo:
#
# * Un gerente de producción puede tomar una muestra de un producto para determinar si cumple con ciertas especificaciones de calidad.
# * Un funcionario del gobierno tomará una muestra de los residentes para decidir si cierto plan tributario o programa de bienestar social producirá los resultados deseados.
# * Un académico tomará muestras de estudiantes para evaluar el impacto de una nueva plataforma de aprendizaje introducida en pandemia.
#
# ## <font color='green'>**Actividad 1**</font>
#
# * Desarrolle algunos ajemplos adicionales en los cuales tiene sentido el tomar decisiones en basea muestras. Piense en su día a día.

# %% [markdown]
# Tu respuesta aquí ...
#
# 1. Una proudcción de manzanas necesita saber si cumple con los diametros de calidad esperados por los consumidores.
#
# 2. Se desea evaluar la respuesta de un farmaco frente a una enfermedad.
#
# 3. Se debe cuantificar el agrado/desagrado que produciria una publicidad para un nuevo telefono movil.
#
# <font color='green'>Fin actividad 1</font>

# %% [markdown]
# Por lo general las muestras tienen un impacto muy directo en las decisiones que se toman, por tanto toda conclusión que se obtenga o todo conocimiento que se decodifique respecto a una muestra es muy importante.
#
# Una aplicación muy común y de gran utilidad en una distribución muestral es la de determinar la probabilidad de que una media muestral clasifique dentro de un rango dado (probabilidad que la media muestral sea menor que, mayor que, o entre un rango determinado). Esto funciona debido a que la distribución muestral estará distribuida normalmente por las siguientes razones:
#  * las muestras provienen de una población normal, o
#  * el tamaño de las muestras es de $n \ge 30$, independiente de la distribución de la población, ya que el Teorema del Límite Central garantiza la normalidad en el proceso de muestreo.

# %% [markdown]
# ### Veamos un ejemplo
#
# El diamétro de las tortas de Girasol se distribuye normalmente con media 18 cm y desviación estandar de 6 cm. En una muestra de 10 tortas, ¿Cuál es la probabilidad de encontrar tortas de diámetro promedio inferior a 16 cm?
#
# 1. Calcularemos los estadísticos
# 2. Visualizaremos la Función de Densidad de Probabilidad de la población y de las muestras.
# 3. Calcularemos la propabilidad solicitada.

# %%
# X = Diámetro tortas, sigue una Distribución Normal =>    𝑋~𝑁(18;6)
# Definir parámetros 𝑋~N(mu, sigma) 
Mu = 18
Sigma = 6  #sigma población


# Estadisticos 𝑋barra~𝑁(18; 6/√10), debido a que Población es Normal y 
# como se conoce Sigma población, esto a pesar de ser una muestra <30.
# 𝑋barra~N(Mu, sigma/raiz(n)) 
n = 10
xbarra_barra = Mu
Sigma_xbarra = Sigma / np.sqrt(n) #TLC  Sigma muestral = Sigma pob / raiz (n)

# Visualizar
# Graficando la distribución normal de población y medias

# Proyectar distribución población
poblacion = stats.norm(Mu, Sigma)
x = np.linspace(poblacion.ppf(0.00001), poblacion.ppf(0.99999), 100)
pdf = poblacion.pdf(x) #funcion densidad probabilidad

#proyectar distribución medias n=10
medias = stats.norm(xbarra_barra, Sigma_xbarra)
x_m = np.linspace(medias.ppf(0.00001), medias.ppf(0.99999), 100)
pdf_m = medias.pdf(x_m) #funcion densidad probabilidad

limite = 16 #limite

plt.figure(figsize=(10, 5)) #tamaño gráfico
plt.plot(x, pdf,"r") #poblacion fit
plt.plot(x_m, pdf_m,"b", ) #medias fit
plt.vlines(ymin=0, ymax=0.2, x=limite)#Limite
plt.legend(['Población','Muestras', 'Límite'])
plt.show()

# %%
# En una muestra de 10 tortas, ¿Cuál es la probabilidad de encontrar tortas 
# de diámetro promedio inferior a 16 cm?
# 𝑃(𝑥barra ≤ 16)

# calcular 𝑃(𝑥barra ≤ 16)

prob_16 = stats.norm(Mu, Sigma_xbarra).cdf(limite)
print(f'Prob <= 16: {prob_16: 6.4f}')
# Out:
# Prob <= 16:  0.1459

# %% [markdown]
# ## <font color='green'>**Actividad 2**</font>
#
# Una población de fuentes de alimentación para micro-computadores tiene un voltaje de salida (output) que sigue una distribución normal de media 5 voltios y desviación estándar 0.1 voltios. Se extrae una muestra aleatoria simple de 8 alimentadores.
#
# 1. Obtener la distribución de $\bar{x}$
# 2. Hallar la probabilidad de que el valor de $\bar{x}$ se desvíe en más de 0.05 voltios de la media poblacional $\mu$ conocida.

# %%
# X = Voltaje de salida de fuentes de alimentación para micro-computadores, sigue una Distribución Normal =>    𝑋~𝑁(5;0.1)
# Definir parámetros 𝑋~N(mu, sigma) 
Mu = 5
Sigma = 0.1  #sigma población

# Estadisticos 𝑋barra~𝑁(5; 0.1/√8), debido a que Población es Normal y 
# como se conoce Sigma población, esto a pesar de ser una muestra <30.
# 𝑋barra~N(Mu, sigma/raiz(n)) 
n = 8
xbarra_barra = Mu
Sigma_xbarra = Sigma / np.sqrt(n) #TLC  Sigma muestral = Sigma pob / raiz (n)

# imprimir estadisticos
print(f'Variable aleatoria: X = Voltaje de salida de fuentes de alimentación para micro-computadores, sigue una Distribución Normal')
print(f'La media poblacional de X es de {Mu}')
print(f'La desviación estandar poblacional de X es de {Sigma: 2.4}')
print()
print(f'La media muestra de X es de {xbarra_barra}')
print(f'La desviación estandar muestral de X es de {Sigma_xbarra: 2.4}')

# Visualizar
# Graficando la distribución normal de población y medias

# Proyectar distribución población
poblacion = stats.norm(Mu, Sigma)
x = np.linspace(poblacion.ppf(0.00001), poblacion.ppf(0.99999), 100)
pdf = poblacion.pdf(x) #funcion densidad probabilidad

#proyectar distribución medias n=8
medias = stats.norm(xbarra_barra, Sigma_xbarra)
x_m = np.linspace(medias.ppf(0.00001), medias.ppf(0.99999), 100)
pdf_m = medias.pdf(x_m) #funcion densidad probabilidad

limite1 = xbarra_barra-0.05 #limite
limite2 = xbarra_barra+0.05 #limite

plt.figure(figsize=(10, 5)) #tamaño gráfico
plt.plot(x, pdf,"r", label='Población') #poblacion fit
plt.plot(x_m, pdf_m,"b", label = 'Muestras') #medias fit
plt.vlines(ymin=0, ymax=12, x=limite1)#Limite
plt.vlines(ymin=0, ymax=12, x=limite2)#Limite

plt.legend()
plt.show()
# Out:
# Variable aleatoria: X = Voltaje de salida de fuentes de alimentación para micro-computadores, sigue una Distribución Normal
# La media poblacional de X es de 5
# La desviación estandar poblacional de X es de  0.1
#
# La media muestra de X es de 5
# La desviación estandar muestral de X es de  0.03536

# %%
# Hallar la probabilidad de que el valor de  x¯  se desvíe en más de 0.05 voltios de la media poblacional  μ  conocida.

prob_menos = stats.norm(Mu, Sigma_xbarra).cdf(Mu-0.05)
prob_mas   = 1 - stats.norm(Mu, Sigma_xbarra).cdf(Mu+0.05)
print(f'Prob(|x\u0302 - \u03BC| > 0.05) : {prob_menos + prob_mas: 6.4f}')
print(f'La probabilidad de que el valor x\u0302 se desvie en más de 0.05 voltios de \u03BC es de {prob_menos + prob_mas: 6.4f}')
# Out:
# Prob(|x̂ - μ| > 0.05) :  0.1573
# La probabilidad de que el valor x̂ se desvie en más de 0.05 voltios de μ es de  0.1573

# %% [markdown]
# <font color='green'>Fin actividad 2</font>

# %% [markdown]
# ## <font color='green'>**Actividad 3**</font>
#
# Las latas de cerveza vendidas por KOTMAN tienen un promedio de 16.1 onzas, con una desviación estándar de 1.2 onzas (se asume población normal).
# Si se toma una muestra de de $n=200$, cuál es la probabilidad de que la media sea:
# 1. ¿menos que 16.27 onzas?
# 2. ¿por lo menos 15.93?
# 3. Si la especificación de calidad (VoC = Voz del Cliente) indica que las cervezas deben contener entre 13.1 y 18.5 onzas, ¿qué porcentaje no cumple la voz del cliente?

# %%
# X = Onzas en latas de cervezas de KOTMAN, sigue una Distribución Normal =>    𝑋~𝑁(16.1;1.2)
# Definir parámetros 𝑋~N(mu, sigma) 
Mu = 16.1
Sigma = 1.2  #sigma población

# Estadisticos 𝑋barra~𝑁(16.1; 1.2/√200), debido a que Población es Normal y 
# como se conoce Sigma población, esto a pesar de ser una muestra <30.
# 𝑋barra~N(Mu, sigma/raiz(n)) 
n = 200
xbarra_barra = Mu
Sigma_xbarra = Sigma / np.sqrt(n) #TLC  Sigma muestral = Sigma pob / raiz (n)

# imprimir estadisticos
print(f'Variable aleatoria: X = Onzas en latas de cervezas de KOTMAN, sigue una Distribución Normal')
print(f'La media poblacional de X es de {Mu}')
print(f'La desviación estandar poblacional de X es de {Sigma: 2.4}')
print()
print(f'La media muestra de X es de {xbarra_barra}')
print(f'La desviación estandar muestral de X es de {Sigma_xbarra: 2.4}')

# Visualizar
# Graficando la distribución normal de población y medias

# Proyectar distribución población
poblacion = stats.norm(Mu, Sigma)
x = np.linspace(poblacion.ppf(0.00001), poblacion.ppf(0.99999), 100)
pdf = poblacion.pdf(x) #funcion densidad probabilidad

#proyectar distribución medias n=8
medias = stats.norm(xbarra_barra, Sigma_xbarra)
x_m = np.linspace(medias.ppf(0.00001), medias.ppf(0.99999), 100)
pdf_m = medias.pdf(x_m) #funcion densidad probabilidad

limite1 = 16.27 #limite
limite2 = 15.93 #limite

plt.figure(figsize=(10, 5)) #tamaño gráfico
plt.plot(x, pdf,"r", label='Población') #poblacion fit
plt.plot(x_m, pdf_m,"b", label = 'Muestras') #medias fit
plt.vlines(ymin=0, ymax=4, x=limite1, color='g')#Limite
plt.vlines(ymin=0, ymax=4, x=limite2, color='k')#Limite

plt.legend()
plt.show()
# Out:
# Variable aleatoria: X = Onzas en latas de cervezas de KOTMAN, sigue una Distribución Normal
# La media poblacional de X es de 16.1
# La desviación estandar poblacional de X es de  1.2
#
# La media muestra de X es de 16.1
# La desviación estandar muestral de X es de  0.08485

# %%
# 1. ¿menos que 16.27 onzas?

prob_1627 = stats.norm(Mu, Sigma_xbarra).cdf(16.27)
prob_1627

print(f'La probabilidad de que la media muestral se menos de 16.27 onzas es de {prob_1627 :2.3}')
# Out:
# La probabilidad de que la media muestral se menos de 16.27 onzas es de 0.977

# %%
# 2. ¿por lo menos 15.93?

prob_1593 = 1 - stats.norm(Mu, Sigma_xbarra).cdf(15.93)
prob_1593

print(f'La probabilidad de que la media muestral sea por lo menos de 15.93 onzas es de {prob_1593 :2.3}')
# Out:
# La probabilidad de que la media muestral sea por lo menos de 15.93 onzas es de 0.977

# %%
# 3. Si la especificación de calidad (VoC = Voz del Cliente) indica que las cervezas deben contener entre 13.1 y 18.5 onzas, ¿qué porcentaje no cumple la voz del cliente?
# Para contestar esto se utiliza la distribución poblacional

prob_131 = stats.norm(Mu, Sigma).cdf(13.1)
prob_131

prob_185 = 1 - stats.norm(Mu, Sigma).cdf(18.5)
prob_185

print(f'La probabilidad de que la media poblacional este entre 13.1 y 18.5 onzas es de {1 - (prob_131 + prob_185) :2.3}')
print(f'Por lo tanto, las cervezas que no cumplen con la Voz del Cliente son de {(prob_131 + prob_185)*100: 2.3} %')
# Out:
# La probabilidad de que la media poblacional este entre 13.1 y 18.5 onzas es de 0.971
# Por lo tanto, las cervezas que no cumplen con la Voz del Cliente son de  2.9 %

# %% [markdown]
# <font color='green'>Fin actividad 3</font>

# %% [markdown]
# ## <font color='blue'>Distribución de Proporciones Muestrales</font>
#
# Existen muchos desafíos de negocios que tratan sobre la proporción de la población, en particular en aquellos en los cuales la variable a estudiar es un atributo cualitativo; denotaremos esta proporción como $\pi$ o $p$. Veamos unos ejemplos:
# * Una empresa de marketing puede querer averiguar si un cliente __compra (1)__ o  __no compra (0)__ el producto.
# * Un banco con frecuencia debe determinar si un cliente __continuará (1)__ o __no continuará (0)__ siendo cliente al finalizar el mes.
# * Un servicio digital (música) necesita saber si sus clientes en modo freemium __se convertirán en subscriptores premium (1)__ o __seguirán siendo usarios en modo gratuito (0)__.
# * Muchas compañias para asignar presupuesto a sus estrategias, deben determinar la probabilidad de que un proyecto __generará (1)__ o __no generará (0)__ un rendimiento positivo.
#
# Cuando en una población procedemos a estudiar una característica con solo __dos posibles valores (éxito: 1 o fracaso: 0)__, entonces la __población sigue una distribución binomial__.
#
# Al tomar muestras de la población, cada muestra tendrá un porcentaje de individuos que tiene esa característica, donde $p$ es la __proporción de éxito__ de esta variable aleatoria de la población. La proporción de fracaso es $q$, la cual se calcula como $q = 1 – p$.
#
# La distribución asociada a la variable aleatoria que une cada muestra con su proporción se llama __distribución muestral de proporciones__.
#
# Como, para poblaciones grandes, la binomial se aproxima a la normal, la distribución muestral de proporciones también sigue una distribución normal con la siguiente forma:
# $$\hat{p} \sim N(p, \sqrt{\frac{p\:(1-p)}{n}})$$
#
#
# Esto siempre que $n$ sea suficientemente grande ($n \ge 30$), y $n \times p \ge 5$, $n \times q \ge 5$.
#
# En estos casos se utiliza la __media de proporción muestral__ para estimar el parámetro desconocido $\pi$ o $p$.
#
# $$E(\hat{p}) = \mu_{\hat{p}} = \frac{\mu_x}{n} = \frac{np}{n} = p$$
#
# $$\sqrt{V_{\hat{p}}} = \frac{V(X)}{n} = \frac{\sqrt{np\:(1-p)}}{n} = \sqrt{\frac{np\:(1-p)}{n^2}} =  \sqrt{\frac{p\:(1-p)}{n}}$$
#
# si:
# $$n \ge 30$$ <br>
# $$np \ge 5$$ y <br>
# $$np(1-p) \ge 5$$
#
# Entonces:
#
# $$\hat{p} \sim N(p, \sqrt{\frac{p\:(1-p)}{n}})$$

# %% [markdown]
# Como vemos el proceso de las __proporciones muestrales__ es muy similar al que vimos en las __medias muestrales__.
#
# <img src='https://drive.google.com/uc?export=view&id=17EucJTprgc6AhG-BvQpIpo_0iL3kHsZX' width="800" align="left" style="margin-right: 20px">
# <br>

# %% [markdown]
# A continuación, veamos un ejemplo en el cual tenemos una población de 10.000 clientes, de los cuales el 60% de ellos dicen estar satisfechos (1) con el servicio recibido, y el 40% restante, no lo está (0). Crearemos una población ficticia con estos parámetros, extraeremos varias muestras a las cuales calcularemos la __proporción muestral__ para, posteriormente, graficar la distribución de dichas proporciones.

# %%
# Creamos población de 10000 clientes "Satisfechos: 1 " o "No satisfechos: 0", 
# donde el 60% está Satisfecho

N = 10000
n = 1
p = 0.6

# creo una población de ceros y unos (clientes "satisfechos" y "no satisfechos")
pob = np.random.RandomState(seed=2).binomial(n, p, size=N)

# graficar histograma de la población
plt.hist(pob, density=True)
plt.show

# calcular parámetros
prop_pob = np.mean(pob) # Note que una proporción es una media de ceros y unos!
sigma_pob = np.std(pob)

print(f'Proporción poblacional: {prop_pob:6.4f}')
print(f'Desviación estándar poblacional: {sigma_pob:6.4f}')

# Otra forma
sigma_pob2 = np.sqrt(prop_pob * (1 - prop_pob))
print(f'Otra forma de sigma: {sigma_pob2:6.4f}')
# Out:
# Proporción poblacional: 0.6119
# Desviación estándar poblacional: 0.4873
# Otra forma de sigma: 0.4873

# %% [markdown]
# Lo mismo pero con `scipy.stats`

# %%
# Graficando Binomial
n, p = 1, 0.6 # parámetros de forma 
binomial = stats.binom(n, p) # Distribución
pob2 = binomial.rvs(size=N)
plt.hist(pob2, density=True)
plt.show()

# %%
stats.bernoulli(p).rvs(10)
# Out:
# array([1, 1, 1, 0, 1, 0, 1, 0, 1, 1])

# %%
# Muestreo
# sacar m muestras de tamaño n, calcular la proporción muestral

n = 50
m = 100
muestras = []
for i in range(m):
    muestras_n = np.random.choice(pob, n, replace=False)
    #Ahora calculamos la proporción muestral (p muestra) de cada muestra
    muestras.append(muestras_n.mean())

for i, m in enumerate(muestras):
    print(f'Muestra {i} \tp muestra: {m:4.2f}')
# Out:
# Muestra 0 	p muestra: 0.66
# Muestra 1 	p muestra: 0.60
# Muestra 2 	p muestra: 0.56
# Muestra 3 	p muestra: 0.62
# Muestra 4 	p muestra: 0.70
# Muestra 5 	p muestra: 0.66
# Muestra 6 	p muestra: 0.78
# Muestra 7 	p muestra: 0.60
# Muestra 8 	p muestra: 0.58
# Muestra 9 	p muestra: 0.58
# Muestra 10 	p muestra: 0.58
# Muestra 11 	p muestra: 0.68
# Muestra 12 	p muestra: 0.64
# Muestra 13 	p muestra: 0.54
# Muestra 14 	p muestra: 0.62
# Muestra 15 	p muestra: 0.54
# Muestra 16 	p muestra: 0.48
# Muestra 17 	p muestra: 0.58
# Muestra 18 	p muestra: 0.70
# Muestra 19 	p muestra: 0.58
# Muestra 20 	p muestra: 0.70
# Muestra 21 	p muestra: 0.70
# Muestra 22 	p muestra: 0.66
# Muestra 23 	p muestra: 0.52
# Muestra 24 	p muestra: 0.54
# Muestra 25 	p muestra: 0.60
# Muestra 26 	p muestra: 0.56
# Muestra 27 	p muestra: 0.72
# Muestra 28 	p muestra: 0.68
# Muestra 29 	p muestra: 0.68
# Muestra 30 	p muestra: 0.70
# Muestra 31 	p muestra: 0.54
# Muestra 32 	p muestra: 0.66
# Muestra 33 	p muestra: 0.80
# Muestra 34 	p muestra: 0.66
# Muestra 35 	p muestra: 0.54
# Muestra 36 	p muestra: 0.60
# Muestra 37 	p muestra: 0.56
# Muestra 38 	p muestra: 0.56
# Muestra 39 	p muestra: 0.62
# Muestra 40 	p muestra: 0.62
# Muestra 41 	p muestra: 0.62
# Muestra 42 	p muestra: 0.72
# Muestra 43 	p muestra: 0.66
# Muestra 44 	p muestra: 0.62
# Muestra 45 	p muestra: 0.60
# Muestra 46 	p muestra: 0.66
# Muestra 47 	p muestra: 0.68
# Muestra 48 	p muestra: 0.66
# Muestra 49 	p muestra: 0.66
# Muestra 50 	p muestra: 0.70
# Muestra 51 	p muestra: 0.66
# Muestra 52 	p muestra: 0.68
# Muestra 53 	p muestra: 0.56
# Muestra 54 	p muestra: 0.50
# Muestra 55 	p muestra: 0.58
# Muestra 56 	p muestra: 0.58
# Muestra 57 	p muestra: 0.62
# Muestra 58 	p muestra: 0.60
# Muestra 59 	p muestra: 0.66
# Muestra 60 	p muestra: 0.56
# Muestra 61 	p muestra: 0.58
# Muestra 62 	p muestra: 0.58
# Muestra 63 	p muestra: 0.66
# Muestra 64 	p muestra: 0.62
# Muestra 65 	p muestra: 0.62
# Muestra 66 	p muestra: 0.70
# Muestra 67 	p muestra: 0.62
# Muestra 68 	p muestra: 0.58
# Muestra 69 	p muestra: 0.70
# Muestra 70 	p muestra: 0.64
# Muestra 71 	p muestra: 0.62
# Muestra 72 	p muestra: 0.54
# Muestra 73 	p muestra: 0.64
# Muestra 74 	p muestra: 0.60
# Muestra 75 	p muestra: 0.42
# Muestra 76 	p muestra: 0.50
# Muestra 77 	p muestra: 0.56
# Muestra 78 	p muestra: 0.64
# Muestra 79 	p muestra: 0.58
# Muestra 80 	p muestra: 0.68
# Muestra 81 	p muestra: 0.68
# Muestra 82 	p muestra: 0.64
# Muestra 83 	p muestra: 0.58
# Muestra 84 	p muestra: 0.56
# Muestra 85 	p muestra: 0.64
# Muestra 86 	p muestra: 0.50
# Muestra 87 	p muestra: 0.54
# Muestra 88 	p muestra: 0.62
# Muestra 89 	p muestra: 0.62
# Muestra 90 	p muestra: 0.60
# Muestra 91 	p muestra: 0.60
# Muestra 92 	p muestra: 0.60
# Muestra 93 	p muestra: 0.72
# Muestra 94 	p muestra: 0.62
# Muestra 95 	p muestra: 0.58
# Muestra 96 	p muestra: 0.56
# Muestra 97 	p muestra: 0.70
# Muestra 98 	p muestra: 0.62
# Muestra 99 	p muestra: 0.40

# %%
# Crearemos la lista de p muestral (proporciones muestrales) para después 
# graficar y ejecutar test de normalidad

p_barra = np.mean(muestras)
sigma_pbar = np.std(muestras)
print(f"Media de proporciones: {p_barra: 6.4f}")
print(f"sigma de proporciones: {sigma_pbar: 6.4f}")

plt.hist(muestras, bins=8, density=True) 
plt.show()
# Out:
# Media de proporciones:  0.6154
# sigma de proporciones:  0.0673

# %% [markdown]
# ### Test de normalidad
#
# Para comprobar si los datos siguen una distribución normal, utilizaremos un test de normalidad denominado __Anderson-Darling__, el cual evalúa la hipótesis:
#
# $H_0$: los datos __siguen__ una distribución normal
#
# $H_1$: los datos __NO siguen__ una distribución normal
#
# Si el valor arrojado (Test estadístico de Anderson-Darling) es menor al valor crítico dado para un cierto nivel de significancia (e.g.: 5%), no se puede rechazar la hipótesis $H_0$, i.e., los datos tienen una distribución normal.
#
# Generaremos una gráfica de probabilidad de datos de muestra contra los cuantiles de una distribución teórica específica (la distribución normal por defecto). Utilizaremos la función `probplot`, la cual calcula opcionalmente una línea de mejor ajuste para los datos y traza los resultados usando Matplotlib o una función de trazado dada.

# %%
# crear gráfico de probabilidad
fig, ax = plt.subplots(1,1, figsize=(10,6))
x = muestras
prob = stats.probplot(x, dist=stats.norm, plot=ax)
ax.set_xlabel(None)
ax.set_title('Probpplot contra distribución normal')

#comprobar normalidad de los datos con Anderson-Darling
tsad = stats.anderson(muestras, dist='norm')

# %%
print(f'Test estadístico de Anderson-Darling: {tsad[0]:6.4f}')
print(f'Valores críticos: {tsad[1]}')
print(f'Niveles de significancia: {tsad[2]}')
# Out:
# Test estadístico de Anderson-Darling: 0.7039
# Valores críticos: [0.555 0.632 0.759 0.885 1.053]
# Niveles de significancia: [15.  10.   5.   2.5  1. ]

# %% [markdown]
# ## <font color='green'>Actividad 4</font>
#
# Se ha determinado que el 60% de los estudiantes de una universidad fuman cigarrillos. Se toma una muestra aleatoria de 800 estudiantes.
# 1. Calcule la probabilidad de que la proporción de la muestra de la gente que fuma cigarrillos sea menor que 0.55.
# 2. Visualice la distribución y el límite (0.55)

# %%
# X = Estudiantes de una universidad que fuman cigarillos (1: "Si fuman"/ 0: "No fuman")

# Graficando Binomial
N = 10000
n, p = 1, 0.6 # parámetros de forma 
binomial = stats.binom(n, p) # Distribución
pob2 = binomial.rvs(size=N)
plt.hist(pob2, density=True)
plt.show()

# Muestreo
# sacar m muestras de tamaño n, calcular la proporción muestral

n = 100
m = 800 #muestras aleatorias de 800 estudiantes
muestras = []
for i in range(m):
    muestras_n = np.random.choice(pob2, n, replace=False)
    #Ahora calculamos la proporción muestral (p muestra) de cada muestra
    muestras.append(muestras_n.mean())

for i, m in enumerate(muestras):
    print(f'Muestra {i} \tp muestra: {m:4.2f}')
# Out:
# Muestra 0 	p muestra: 0.55
# Muestra 1 	p muestra: 0.59
# Muestra 2 	p muestra: 0.56
# Muestra 3 	p muestra: 0.57
# Muestra 4 	p muestra: 0.73
# Muestra 5 	p muestra: 0.55
# Muestra 6 	p muestra: 0.60
# Muestra 7 	p muestra: 0.55
# Muestra 8 	p muestra: 0.58
# Muestra 9 	p muestra: 0.66
# Muestra 10 	p muestra: 0.59
# Muestra 11 	p muestra: 0.58
# Muestra 12 	p muestra: 0.63
# Muestra 13 	p muestra: 0.53
# Muestra 14 	p muestra: 0.56
# Muestra 15 	p muestra: 0.53
# Muestra 16 	p muestra: 0.63
# Muestra 17 	p muestra: 0.67
# Muestra 18 	p muestra: 0.63
# Muestra 19 	p muestra: 0.64
# Muestra 20 	p muestra: 0.68
# Muestra 21 	p muestra: 0.62
# Muestra 22 	p muestra: 0.63
# Muestra 23 	p muestra: 0.62
# Muestra 24 	p muestra: 0.65
# Muestra 25 	p muestra: 0.59
# Muestra 26 	p muestra: 0.53
# Muestra 27 	p muestra: 0.61
# Muestra 28 	p muestra: 0.59
# Muestra 29 	p muestra: 0.58
# Muestra 30 	p muestra: 0.57
# Muestra 31 	p muestra: 0.56
# Muestra 32 	p muestra: 0.63
# Muestra 33 	p muestra: 0.56
# Muestra 34 	p muestra: 0.66
# Muestra 35 	p muestra: 0.62
# Muestra 36 	p muestra: 0.59
# Muestra 37 	p muestra: 0.45
# Muestra 38 	p muestra: 0.58
# Muestra 39 	p muestra: 0.50
# Muestra 40 	p muestra: 0.56
# Muestra 41 	p muestra: 0.59
# Muestra 42 	p muestra: 0.47
# Muestra 43 	p muestra: 0.57
# Muestra 44 	p muestra: 0.56
# Muestra 45 	p muestra: 0.73
# Muestra 46 	p muestra: 0.68
# Muestra 47 	p muestra: 0.61
# Muestra 48 	p muestra: 0.68
# Muestra 49 	p muestra: 0.55
# Muestra 50 	p muestra: 0.53
# Muestra 51 	p muestra: 0.46
# Muestra 52 	p muestra: 0.49
# Muestra 53 	p muestra: 0.63
# Muestra 54 	p muestra: 0.71
# Muestra 55 	p muestra: 0.59
# Muestra 56 	p muestra: 0.60
# Muestra 57 	p muestra: 0.66
# Muestra 58 	p muestra: 0.60
# Muestra 59 	p muestra: 0.59
# Muestra 60 	p muestra: 0.56
# Muestra 61 	p muestra: 0.55
# Muestra 62 	p muestra: 0.55
# Muestra 63 	p muestra: 0.62
# Muestra 64 	p muestra: 0.48
# Muestra 65 	p muestra: 0.55
# Muestra 66 	p muestra: 0.58
# Muestra 67 	p muestra: 0.64
# Muestra 68 	p muestra: 0.64
# Muestra 69 	p muestra: 0.52
# Muestra 70 	p muestra: 0.58
# Muestra 71 	p muestra: 0.63
# Muestra 72 	p muestra: 0.62
# Muestra 73 	p muestra: 0.56
# Muestra 74 	p muestra: 0.58
# Muestra 75 	p muestra: 0.64
# Muestra 76 	p muestra: 0.64
# Muestra 77 	p muestra: 0.61
# Muestra 78 	p muestra: 0.58
# Muestra 79 	p muestra: 0.55
# Muestra 80 	p muestra: 0.63
# Muestra 81 	p muestra: 0.55
# Muestra 82 	p muestra: 0.58
# Muestra 83 	p muestra: 0.62
# Muestra 84 	p muestra: 0.54
# Muestra 85 	p muestra: 0.66
# Muestra 86 	p muestra: 0.60
# Muestra 87 	p muestra: 0.58
# Muestra 88 	p muestra: 0.61
# Muestra 89 	p muestra: 0.54
# Muestra 90 	p muestra: 0.68
# Muestra 91 	p muestra: 0.53
# Muestra 92 	p muestra: 0.64
# Muestra 93 	p muestra: 0.58
# Muestra 94 	p muestra: 0.60
# Muestra 95 	p muestra: 0.56
# Muestra 96 	p muestra: 0.66
# Muestra 97 	p muestra: 0.65
# Muestra 98 	p muestra: 0.64
# Muestra 99 	p muestra: 0.52
# Muestra 100 	p muestra: 0.69
# Muestra 101 	p muestra: 0.65
# Muestra 102 	p muestra: 0.59
# Muestra 103 	p muestra: 0.58
# Muestra 104 	p muestra: 0.62
# Muestra 105 	p muestra: 0.66
# Muestra 106 	p muestra: 0.51
# Muestra 107 	p muestra: 0.65
# Muestra 108 	p muestra: 0.61
# Muestra 109 	p muestra: 0.66
# Muestra 110 	p muestra: 0.51
# Muestra 111 	p muestra: 0.51
# Muestra 112 	p muestra: 0.62
# Muestra 113 	p muestra: 0.63
# Muestra 114 	p muestra: 0.66
# Muestra 115 	p muestra: 0.63
# Muestra 116 	p muestra: 0.58
# Muestra 117 	p muestra: 0.59
# Muestra 118 	p muestra: 0.61
# Muestra 119 	p muestra: 0.52
# Muestra 120 	p muestra: 0.56
# Muestra 121 	p muestra: 0.55
# Muestra 122 	p muestra: 0.53
# Muestra 123 	p muestra: 0.62
# Muestra 124 	p muestra: 0.59
# Muestra 125 	p muestra: 0.64
# Muestra 126 	p muestra: 0.49
# Muestra 127 	p muestra: 0.58
# Muestra 128 	p muestra: 0.56
# Muestra 129 	p muestra: 0.54
# Muestra 130 	p muestra: 0.58
# Muestra 131 	p muestra: 0.63
# Muestra 132 	p muestra: 0.63
# Muestra 133 	p muestra: 0.58
# Muestra 134 	p muestra: 0.65
# Muestra 135 	p muestra: 0.65
# Muestra 136 	p muestra: 0.63
# Muestra 137 	p muestra: 0.61
# Muestra 138 	p muestra: 0.61
# Muestra 139 	p muestra: 0.70
# Muestra 140 	p muestra: 0.59
# Muestra 141 	p muestra: 0.69
# Muestra 142 	p muestra: 0.60
# Muestra 143 	p muestra: 0.54
# Muestra 144 	p muestra: 0.59
# Muestra 145 	p muestra: 0.60
# Muestra 146 	p muestra: 0.61
# Muestra 147 	p muestra: 0.61
# Muestra 148 	p muestra: 0.57
# Muestra 149 	p muestra: 0.62
# Muestra 150 	p muestra: 0.58
# Muestra 151 	p muestra: 0.60
# Muestra 152 	p muestra: 0.64
# Muestra 153 	p muestra: 0.60
# Muestra 154 	p muestra: 0.55
# Muestra 155 	p muestra: 0.61
# Muestra 156 	p muestra: 0.65
# Muestra 157 	p muestra: 0.63
# Muestra 158 	p muestra: 0.62
# Muestra 159 	p muestra: 0.58
# Muestra 160 	p muestra: 0.66
# Muestra 161 	p muestra: 0.62
# Muestra 162 	p muestra: 0.64
# Muestra 163 	p muestra: 0.57
# Muestra 164 	p muestra: 0.53
# Muestra 165 	p muestra: 0.61
# Muestra 166 	p muestra: 0.59
# Muestra 167 	p muestra: 0.62
# Muestra 168 	p muestra: 0.66
# Muestra 169 	p muestra: 0.65
# Muestra 170 	p muestra: 0.59
# Muestra 171 	p muestra: 0.63
# Muestra 172 	p muestra: 0.64
# Muestra 173 	p muestra: 0.61
# Muestra 174 	p muestra: 0.62
# Muestra 175 	p muestra: 0.57
# Muestra 176 	p muestra: 0.57
# Muestra 177 	p muestra: 0.63
# Muestra 178 	p muestra: 0.60
# Muestra 179 	p muestra: 0.58
# Muestra 180 	p muestra: 0.63
# Muestra 181 	p muestra: 0.59
# Muestra 182 	p muestra: 0.56
# Muestra 183 	p muestra: 0.65
# Muestra 184 	p muestra: 0.67
# Muestra 185 	p muestra: 0.55
# Muestra 186 	p muestra: 0.63
# Muestra 187 	p muestra: 0.65
# Muestra 188 	p muestra: 0.57
# Muestra 189 	p muestra: 0.58
# Muestra 190 	p muestra: 0.60
# Muestra 191 	p muestra: 0.55
# Muestra 192 	p muestra: 0.57
# Muestra 193 	p muestra: 0.64
# Muestra 194 	p muestra: 0.52
# Muestra 195 	p muestra: 0.53
# Muestra 196 	p muestra: 0.61
# Muestra 197 	p muestra: 0.62
# Muestra 198 	p muestra: 0.57
# Muestra 199 	p muestra: 0.61
# Muestra 200 	p muestra: 0.63
# Muestra 201 	p muestra: 0.62
# Muestra 202 	p muestra: 0.66
# Muestra 203 	p muestra: 0.66
# Muestra 204 	p muestra: 0.50
# Muestra 205 	p muestra: 0.63
# Muestra 206 	p muestra: 0.55
# Muestra 207 	p muestra: 0.62
# Muestra 208 	p muestra: 0.61
# Muestra 209 	p muestra: 0.68
# Muestra 210 	p muestra: 0.59
# Muestra 211 	p muestra: 0.58
# Muestra 212 	p muestra: 0.55
# Muestra 213 	p muestra: 0.61
# Muestra 214 	p muestra: 0.60
# Muestra 215 	p muestra: 0.59
# Muestra 216 	p muestra: 0.56
# Muestra 217 	p muestra: 0.57
# Muestra 218 	p muestra: 0.58
# Muestra 219 	p muestra: 0.59
# Muestra 220 	p muestra: 0.58
# Muestra 221 	p muestra: 0.56
# Muestra 222 	p muestra: 0.60
# Muestra 223 	p muestra: 0.52
# Muestra 224 	p muestra: 0.61
# Muestra 225 	p muestra: 0.58
# Muestra 226 	p muestra: 0.62
# Muestra 227 	p muestra: 0.63
# Muestra 228 	p muestra: 0.60
# Muestra 229 	p muestra: 0.56
# Muestra 230 	p muestra: 0.58
# Muestra 231 	p muestra: 0.65
# Muestra 232 	p muestra: 0.51
# Muestra 233 	p muestra: 0.54
# Muestra 234 	p muestra: 0.74
# Muestra 235 	p muestra: 0.57
# Muestra 236 	p muestra: 0.57
# Muestra 237 	p muestra: 0.60
# Muestra 238 	p muestra: 0.66
# Muestra 239 	p muestra: 0.52
# Muestra 240 	p muestra: 0.57
# Muestra 241 	p muestra: 0.63
# Muestra 242 	p muestra: 0.65
# Muestra 243 	p muestra: 0.67
# Muestra 244 	p muestra: 0.65
# Muestra 245 	p muestra: 0.53
# Muestra 246 	p muestra: 0.64
# Muestra 247 	p muestra: 0.51
# Muestra 248 	p muestra: 0.70
# Muestra 249 	p muestra: 0.58
# Muestra 250 	p muestra: 0.66
# Muestra 251 	p muestra: 0.64
# Muestra 252 	p muestra: 0.60
# Muestra 253 	p muestra: 0.64
# Muestra 254 	p muestra: 0.68
# Muestra 255 	p muestra: 0.62
# Muestra 256 	p muestra: 0.58
# Muestra 257 	p muestra: 0.64
# Muestra 258 	p muestra: 0.64
# Muestra 259 	p muestra: 0.62
# Muestra 260 	p muestra: 0.57
# Muestra 261 	p muestra: 0.54
# Muestra 262 	p muestra: 0.66
# Muestra 263 	p muestra: 0.61
# Muestra 264 	p muestra: 0.58
# Muestra 265 	p muestra: 0.65
# Muestra 266 	p muestra: 0.65
# Muestra 267 	p muestra: 0.63
# Muestra 268 	p muestra: 0.62
# Muestra 269 	p muestra: 0.62
# Muestra 270 	p muestra: 0.58
# Muestra 271 	p muestra: 0.70
# Muestra 272 	p muestra: 0.55
# Muestra 273 	p muestra: 0.57
# Muestra 274 	p muestra: 0.55
# Muestra 275 	p muestra: 0.64
# Muestra 276 	p muestra: 0.57
# Muestra 277 	p muestra: 0.61
# Muestra 278 	p muestra: 0.53
# Muestra 279 	p muestra: 0.53
# Muestra 280 	p muestra: 0.56
# Muestra 281 	p muestra: 0.56
# Muestra 282 	p muestra: 0.60
# Muestra 283 	p muestra: 0.62
# Muestra 284 	p muestra: 0.63
# Muestra 285 	p muestra: 0.59
# Muestra 286 	p muestra: 0.64
# Muestra 287 	p muestra: 0.62
# Muestra 288 	p muestra: 0.64
# Muestra 289 	p muestra: 0.60
# Muestra 290 	p muestra: 0.61
# Muestra 291 	p muestra: 0.63
# Muestra 292 	p muestra: 0.58
# Muestra 293 	p muestra: 0.56
# Muestra 294 	p muestra: 0.67
# Muestra 295 	p muestra: 0.59
# Muestra 296 	p muestra: 0.54
# Muestra 297 	p muestra: 0.68
# Muestra 298 	p muestra: 0.53
# Muestra 299 	p muestra: 0.61
# Muestra 300 	p muestra: 0.71
# Muestra 301 	p muestra: 0.62
# Muestra 302 	p muestra: 0.54
# Muestra 303 	p muestra: 0.54
# Muestra 304 	p muestra: 0.60
# Muestra 305 	p muestra: 0.59
# Muestra 306 	p muestra: 0.66
# Muestra 307 	p muestra: 0.65
# Muestra 308 	p muestra: 0.62
# Muestra 309 	p muestra: 0.57
# Muestra 310 	p muestra: 0.46
# Muestra 311 	p muestra: 0.55
# Muestra 312 	p muestra: 0.48
# Muestra 313 	p muestra: 0.65
# Muestra 314 	p muestra: 0.65
# Muestra 315 	p muestra: 0.54
# Muestra 316 	p muestra: 0.65
# Muestra 317 	p muestra: 0.67
# Muestra 318 	p muestra: 0.63
# Muestra 319 	p muestra: 0.55
# Muestra 320 	p muestra: 0.57
# Muestra 321 	p muestra: 0.64
# Muestra 322 	p muestra: 0.64
# Muestra 323 	p muestra: 0.63
# Muestra 324 	p muestra: 0.56
# Muestra 325 	p muestra: 0.57
# Muestra 326 	p muestra: 0.56
# Muestra 327 	p muestra: 0.60
# Muestra 328 	p muestra: 0.60
# Muestra 329 	p muestra: 0.66
# Muestra 330 	p muestra: 0.63
# Muestra 331 	p muestra: 0.61
# Muestra 332 	p muestra: 0.62
# Muestra 333 	p muestra: 0.65
# Muestra 334 	p muestra: 0.60
# Muestra 335 	p muestra: 0.59
# Muestra 336 	p muestra: 0.62
# Muestra 337 	p muestra: 0.55
# Muestra 338 	p muestra: 0.71
# Muestra 339 	p muestra: 0.54
# Muestra 340 	p muestra: 0.70
# Muestra 341 	p muestra: 0.61
# Muestra 342 	p muestra: 0.62
# Muestra 343 	p muestra: 0.68
# Muestra 344 	p muestra: 0.57
# Muestra 345 	p muestra: 0.63
# Muestra 346 	p muestra: 0.68
# Muestra 347 	p muestra: 0.68
# Muestra 348 	p muestra: 0.60
# Muestra 349 	p muestra: 0.61
# Muestra 350 	p muestra: 0.62
# Muestra 351 	p muestra: 0.64
# Muestra 352 	p muestra: 0.59
# Muestra 353 	p muestra: 0.62
# Muestra 354 	p muestra: 0.63
# Muestra 355 	p muestra: 0.57
# Muestra 356 	p muestra: 0.59
# Muestra 357 	p muestra: 0.66
# Muestra 358 	p muestra: 0.62
# Muestra 359 	p muestra: 0.64
# Muestra 360 	p muestra: 0.62
# Muestra 361 	p muestra: 0.57
# Muestra 362 	p muestra: 0.51
# Muestra 363 	p muestra: 0.56
# Muestra 364 	p muestra: 0.61
# Muestra 365 	p muestra: 0.53
# Muestra 366 	p muestra: 0.66
# Muestra 367 	p muestra: 0.53
# Muestra 368 	p muestra: 0.60
# Muestra 369 	p muestra: 0.56
# Muestra 370 	p muestra: 0.63
# Muestra 371 	p muestra: 0.51
# Muestra 372 	p muestra: 0.56
# Muestra 373 	p muestra: 0.61
# Muestra 374 	p muestra: 0.47
# Muestra 375 	p muestra: 0.63
# Muestra 376 	p muestra: 0.66
# Muestra 377 	p muestra: 0.68
# Muestra 378 	p muestra: 0.57
# Muestra 379 	p muestra: 0.60
# Muestra 380 	p muestra: 0.58
# Muestra 381 	p muestra: 0.63
# Muestra 382 	p muestra: 0.58
# Muestra 383 	p muestra: 0.66
# Muestra 384 	p muestra: 0.67
# Muestra 385 	p muestra: 0.64
# Muestra 386 	p muestra: 0.64
# Muestra 387 	p muestra: 0.62
# Muestra 388 	p muestra: 0.61
# Muestra 389 	p muestra: 0.61
# Muestra 390 	p muestra: 0.56
# Muestra 391 	p muestra: 0.65
# Muestra 392 	p muestra: 0.56
# Muestra 393 	p muestra: 0.63
# Muestra 394 	p muestra: 0.60
# Muestra 395 	p muestra: 0.50
# Muestra 396 	p muestra: 0.56
# Muestra 397 	p muestra: 0.59
# Muestra 398 	p muestra: 0.67
# Muestra 399 	p muestra: 0.55
# Muestra 400 	p muestra: 0.63
# Muestra 401 	p muestra: 0.58
# Muestra 402 	p muestra: 0.58
# Muestra 403 	p muestra: 0.56
# Muestra 404 	p muestra: 0.62
# Muestra 405 	p muestra: 0.66
# Muestra 406 	p muestra: 0.57
# Muestra 407 	p muestra: 0.66
# Muestra 408 	p muestra: 0.62
# Muestra 409 	p muestra: 0.53
# Muestra 410 	p muestra: 0.66
# Muestra 411 	p muestra: 0.54
# Muestra 412 	p muestra: 0.59
# Muestra 413 	p muestra: 0.61
# Muestra 414 	p muestra: 0.66
# Muestra 415 	p muestra: 0.63
# Muestra 416 	p muestra: 0.66
# Muestra 417 	p muestra: 0.64
# Muestra 418 	p muestra: 0.60
# Muestra 419 	p muestra: 0.60
# Muestra 420 	p muestra: 0.54
# Muestra 421 	p muestra: 0.66
# Muestra 422 	p muestra: 0.53
# Muestra 423 	p muestra: 0.58
# Muestra 424 	p muestra: 0.56
# Muestra 425 	p muestra: 0.53
# Muestra 426 	p muestra: 0.64
# Muestra 427 	p muestra: 0.55
# Muestra 428 	p muestra: 0.63
# Muestra 429 	p muestra: 0.54
# Muestra 430 	p muestra: 0.58
# Muestra 431 	p muestra: 0.61
# Muestra 432 	p muestra: 0.57
# Muestra 433 	p muestra: 0.51
# Muestra 434 	p muestra: 0.59
# Muestra 435 	p muestra: 0.64
# Muestra 436 	p muestra: 0.63
# Muestra 437 	p muestra: 0.67
# Muestra 438 	p muestra: 0.55
# Muestra 439 	p muestra: 0.55
# Muestra 440 	p muestra: 0.61
# Muestra 441 	p muestra: 0.59
# Muestra 442 	p muestra: 0.59
# Muestra 443 	p muestra: 0.56
# Muestra 444 	p muestra: 0.64
# Muestra 445 	p muestra: 0.60
# Muestra 446 	p muestra: 0.56
# Muestra 447 	p muestra: 0.60
# Muestra 448 	p muestra: 0.62
# Muestra 449 	p muestra: 0.57
# Muestra 450 	p muestra: 0.53
# Muestra 451 	p muestra: 0.52
# Muestra 452 	p muestra: 0.57
# Muestra 453 	p muestra: 0.59
# Muestra 454 	p muestra: 0.54
# Muestra 455 	p muestra: 0.56
# Muestra 456 	p muestra: 0.68
# Muestra 457 	p muestra: 0.58
# Muestra 458 	p muestra: 0.60
# Muestra 459 	p muestra: 0.65
# Muestra 460 	p muestra: 0.52
# Muestra 461 	p muestra: 0.61
# Muestra 462 	p muestra: 0.53
# Muestra 463 	p muestra: 0.62
# Muestra 464 	p muestra: 0.64
# Muestra 465 	p muestra: 0.57
# Muestra 466 	p muestra: 0.62
# Muestra 467 	p muestra: 0.66
# Muestra 468 	p muestra: 0.61
# Muestra 469 	p muestra: 0.55
# Muestra 470 	p muestra: 0.72
# Muestra 471 	p muestra: 0.61
# Muestra 472 	p muestra: 0.61
# Muestra 473 	p muestra: 0.59
# Muestra 474 	p muestra: 0.67
# Muestra 475 	p muestra: 0.54
# Muestra 476 	p muestra: 0.58
# Muestra 477 	p muestra: 0.63
# Muestra 478 	p muestra: 0.63
# Muestra 479 	p muestra: 0.55
# Muestra 480 	p muestra: 0.49
# Muestra 481 	p muestra: 0.52
# Muestra 482 	p muestra: 0.63
# Muestra 483 	p muestra: 0.54
# Muestra 484 	p muestra: 0.59
# Muestra 485 	p muestra: 0.60
# Muestra 486 	p muestra: 0.63
# Muestra 487 	p muestra: 0.54
# Muestra 488 	p muestra: 0.73
# Muestra 489 	p muestra: 0.54
# Muestra 490 	p muestra: 0.52
# Muestra 491 	p muestra: 0.61
# Muestra 492 	p muestra: 0.56
# Muestra 493 	p muestra: 0.53
# Muestra 494 	p muestra: 0.57
# Muestra 495 	p muestra: 0.60
# Muestra 496 	p muestra: 0.72
# Muestra 497 	p muestra: 0.68
# Muestra 498 	p muestra: 0.61
# Muestra 499 	p muestra: 0.55
# Muestra 500 	p muestra: 0.52
# Muestra 501 	p muestra: 0.54
# Muestra 502 	p muestra: 0.57
# Muestra 503 	p muestra: 0.58
# Muestra 504 	p muestra: 0.53
# Muestra 505 	p muestra: 0.70
# Muestra 506 	p muestra: 0.62
# Muestra 507 	p muestra: 0.56
# Muestra 508 	p muestra: 0.59
# Muestra 509 	p muestra: 0.55
# Muestra 510 	p muestra: 0.50
# Muestra 511 	p muestra: 0.63
# Muestra 512 	p muestra: 0.52
# Muestra 513 	p muestra: 0.50
# Muestra 514 	p muestra: 0.58
# Muestra 515 	p muestra: 0.63
# Muestra 516 	p muestra: 0.62
# Muestra 517 	p muestra: 0.59
# Muestra 518 	p muestra: 0.62
# Muestra 519 	p muestra: 0.63
# Muestra 520 	p muestra: 0.65
# Muestra 521 	p muestra: 0.59
# Muestra 522 	p muestra: 0.62
# Muestra 523 	p muestra: 0.63
# Muestra 524 	p muestra: 0.61
# Muestra 525 	p muestra: 0.64
# Muestra 526 	p muestra: 0.59
# Muestra 527 	p muestra: 0.62
# Muestra 528 	p muestra: 0.60
# Muestra 529 	p muestra: 0.59
# Muestra 530 	p muestra: 0.65
# Muestra 531 	p muestra: 0.64
# Muestra 532 	p muestra: 0.61
# Muestra 533 	p muestra: 0.58
# Muestra 534 	p muestra: 0.55
# Muestra 535 	p muestra: 0.58
# Muestra 536 	p muestra: 0.52
# Muestra 537 	p muestra: 0.55
# Muestra 538 	p muestra: 0.62
# Muestra 539 	p muestra: 0.65
# Muestra 540 	p muestra: 0.61
# Muestra 541 	p muestra: 0.64
# Muestra 542 	p muestra: 0.57
# Muestra 543 	p muestra: 0.65
# Muestra 544 	p muestra: 0.56
# Muestra 545 	p muestra: 0.66
# Muestra 546 	p muestra: 0.65
# Muestra 547 	p muestra: 0.59
# Muestra 548 	p muestra: 0.58
# Muestra 549 	p muestra: 0.56
# Muestra 550 	p muestra: 0.62
# Muestra 551 	p muestra: 0.61
# Muestra 552 	p muestra: 0.55
# Muestra 553 	p muestra: 0.62
# Muestra 554 	p muestra: 0.59
# Muestra 555 	p muestra: 0.54
# Muestra 556 	p muestra: 0.62
# Muestra 557 	p muestra: 0.55
# Muestra 558 	p muestra: 0.61
# Muestra 559 	p muestra: 0.56
# Muestra 560 	p muestra: 0.57
# Muestra 561 	p muestra: 0.62
# Muestra 562 	p muestra: 0.64
# Muestra 563 	p muestra: 0.49
# Muestra 564 	p muestra: 0.59
# Muestra 565 	p muestra: 0.57
# Muestra 566 	p muestra: 0.68
# Muestra 567 	p muestra: 0.58
# Muestra 568 	p muestra: 0.59
# Muestra 569 	p muestra: 0.54
# Muestra 570 	p muestra: 0.53
# Muestra 571 	p muestra: 0.58
# Muestra 572 	p muestra: 0.58
# Muestra 573 	p muestra: 0.59
# Muestra 574 	p muestra: 0.72
# Muestra 575 	p muestra: 0.66
# Muestra 576 	p muestra: 0.65
# Muestra 577 	p muestra: 0.57
# Muestra 578 	p muestra: 0.71
# Muestra 579 	p muestra: 0.61
# Muestra 580 	p muestra: 0.69
# Muestra 581 	p muestra: 0.69
# Muestra 582 	p muestra: 0.68
# Muestra 583 	p muestra: 0.68
# Muestra 584 	p muestra: 0.53
# Muestra 585 	p muestra: 0.59
# Muestra 586 	p muestra: 0.57
# Muestra 587 	p muestra: 0.64
# Muestra 588 	p muestra: 0.59
# Muestra 589 	p muestra: 0.59
# Muestra 590 	p muestra: 0.49
# Muestra 591 	p muestra: 0.67
# Muestra 592 	p muestra: 0.58
# Muestra 593 	p muestra: 0.55
# Muestra 594 	p muestra: 0.60
# Muestra 595 	p muestra: 0.55
# Muestra 596 	p muestra: 0.59
# Muestra 597 	p muestra: 0.54
# Muestra 598 	p muestra: 0.56
# Muestra 599 	p muestra: 0.48
# Muestra 600 	p muestra: 0.60
# Muestra 601 	p muestra: 0.64
# Muestra 602 	p muestra: 0.52
# Muestra 603 	p muestra: 0.66
# Muestra 604 	p muestra: 0.70
# Muestra 605 	p muestra: 0.68
# Muestra 606 	p muestra: 0.58
# Muestra 607 	p muestra: 0.60
# Muestra 608 	p muestra: 0.60
# Muestra 609 	p muestra: 0.58
# Muestra 610 	p muestra: 0.62
# Muestra 611 	p muestra: 0.65
# Muestra 612 	p muestra: 0.61
# Muestra 613 	p muestra: 0.62
# Muestra 614 	p muestra: 0.57
# Muestra 615 	p muestra: 0.54
# Muestra 616 	p muestra: 0.54
# Muestra 617 	p muestra: 0.56
# Muestra 618 	p muestra: 0.61
# Muestra 619 	p muestra: 0.49
# Muestra 620 	p muestra: 0.61
# Muestra 621 	p muestra: 0.66
# Muestra 622 	p muestra: 0.60
# Muestra 623 	p muestra: 0.54
# Muestra 624 	p muestra: 0.60
# Muestra 625 	p muestra: 0.54
# Muestra 626 	p muestra: 0.56
# Muestra 627 	p muestra: 0.59
# Muestra 628 	p muestra: 0.66
# Muestra 629 	p muestra: 0.62
# Muestra 630 	p muestra: 0.51
# Muestra 631 	p muestra: 0.57
# Muestra 632 	p muestra: 0.59
# Muestra 633 	p muestra: 0.58
# Muestra 634 	p muestra: 0.55
# Muestra 635 	p muestra: 0.55
# Muestra 636 	p muestra: 0.58
# Muestra 637 	p muestra: 0.64
# Muestra 638 	p muestra: 0.62
# Muestra 639 	p muestra: 0.62
# Muestra 640 	p muestra: 0.63
# Muestra 641 	p muestra: 0.60
# Muestra 642 	p muestra: 0.64
# Muestra 643 	p muestra: 0.57
# Muestra 644 	p muestra: 0.61
# Muestra 645 	p muestra: 0.69
# Muestra 646 	p muestra: 0.56
# Muestra 647 	p muestra: 0.63
# Muestra 648 	p muestra: 0.56
# Muestra 649 	p muestra: 0.60
# Muestra 650 	p muestra: 0.54
# Muestra 651 	p muestra: 0.78
# Muestra 652 	p muestra: 0.55
# Muestra 653 	p muestra: 0.59
# Muestra 654 	p muestra: 0.67
# Muestra 655 	p muestra: 0.59
# Muestra 656 	p muestra: 0.55
# Muestra 657 	p muestra: 0.66
# Muestra 658 	p muestra: 0.60
# Muestra 659 	p muestra: 0.59
# Muestra 660 	p muestra: 0.71
# Muestra 661 	p muestra: 0.59
# Muestra 662 	p muestra: 0.62
# Muestra 663 	p muestra: 0.61
# Muestra 664 	p muestra: 0.61
# Muestra 665 	p muestra: 0.52
# Muestra 666 	p muestra: 0.55
# Muestra 667 	p muestra: 0.59
# Muestra 668 	p muestra: 0.53
# Muestra 669 	p muestra: 0.61
# Muestra 670 	p muestra: 0.73
# Muestra 671 	p muestra: 0.60
# Muestra 672 	p muestra: 0.53
# Muestra 673 	p muestra: 0.60
# Muestra 674 	p muestra: 0.64
# Muestra 675 	p muestra: 0.58
# Muestra 676 	p muestra: 0.57
# Muestra 677 	p muestra: 0.56
# Muestra 678 	p muestra: 0.56
# Muestra 679 	p muestra: 0.57
# Muestra 680 	p muestra: 0.63
# Muestra 681 	p muestra: 0.62
# Muestra 682 	p muestra: 0.66
# Muestra 683 	p muestra: 0.60
# Muestra 684 	p muestra: 0.67
# Muestra 685 	p muestra: 0.56
# Muestra 686 	p muestra: 0.64
# Muestra 687 	p muestra: 0.61
# Muestra 688 	p muestra: 0.59
# Muestra 689 	p muestra: 0.61
# Muestra 690 	p muestra: 0.61
# Muestra 691 	p muestra: 0.62
# Muestra 692 	p muestra: 0.61
# Muestra 693 	p muestra: 0.61
# Muestra 694 	p muestra: 0.63
# Muestra 695 	p muestra: 0.59
# Muestra 696 	p muestra: 0.65
# Muestra 697 	p muestra: 0.59
# Muestra 698 	p muestra: 0.62
# Muestra 699 	p muestra: 0.59
# Muestra 700 	p muestra: 0.60
# Muestra 701 	p muestra: 0.72
# Muestra 702 	p muestra: 0.62
# Muestra 703 	p muestra: 0.54
# Muestra 704 	p muestra: 0.56
# Muestra 705 	p muestra: 0.53
# Muestra 706 	p muestra: 0.57
# Muestra 707 	p muestra: 0.63
# Muestra 708 	p muestra: 0.62
# Muestra 709 	p muestra: 0.60
# Muestra 710 	p muestra: 0.72
# Muestra 711 	p muestra: 0.56
# Muestra 712 	p muestra: 0.66
# Muestra 713 	p muestra: 0.54
# Muestra 714 	p muestra: 0.55
# Muestra 715 	p muestra: 0.61
# Muestra 716 	p muestra: 0.59
# Muestra 717 	p muestra: 0.63
# Muestra 718 	p muestra: 0.55
# Muestra 719 	p muestra: 0.63
# Muestra 720 	p muestra: 0.59
# Muestra 721 	p muestra: 0.66
# Muestra 722 	p muestra: 0.57
# Muestra 723 	p muestra: 0.57
# Muestra 724 	p muestra: 0.52
# Muestra 725 	p muestra: 0.47
# Muestra 726 	p muestra: 0.53
# Muestra 727 	p muestra: 0.53
# Muestra 728 	p muestra: 0.67
# Muestra 729 	p muestra: 0.57
# Muestra 730 	p muestra: 0.68
# Muestra 731 	p muestra: 0.55
# Muestra 732 	p muestra: 0.54
# Muestra 733 	p muestra: 0.63
# Muestra 734 	p muestra: 0.54
# Muestra 735 	p muestra: 0.58
# Muestra 736 	p muestra: 0.57
# Muestra 737 	p muestra: 0.61
# Muestra 738 	p muestra: 0.57
# Muestra 739 	p muestra: 0.65
# Muestra 740 	p muestra: 0.59
# Muestra 741 	p muestra: 0.59
# Muestra 742 	p muestra: 0.63
# Muestra 743 	p muestra: 0.59
# Muestra 744 	p muestra: 0.63
# Muestra 745 	p muestra: 0.55
# Muestra 746 	p muestra: 0.54
# Muestra 747 	p muestra: 0.60
# Muestra 748 	p muestra: 0.51
# Muestra 749 	p muestra: 0.67
# Muestra 750 	p muestra: 0.63
# Muestra 751 	p muestra: 0.60
# Muestra 752 	p muestra: 0.58
# Muestra 753 	p muestra: 0.66
# Muestra 754 	p muestra: 0.65
# Muestra 755 	p muestra: 0.48
# Muestra 756 	p muestra: 0.59
# Muestra 757 	p muestra: 0.60
# Muestra 758 	p muestra: 0.70
# Muestra 759 	p muestra: 0.61
# Muestra 760 	p muestra: 0.53
# Muestra 761 	p muestra: 0.63
# Muestra 762 	p muestra: 0.61
# Muestra 763 	p muestra: 0.55
# Muestra 764 	p muestra: 0.64
# Muestra 765 	p muestra: 0.61
# Muestra 766 	p muestra: 0.57
# Muestra 767 	p muestra: 0.58
# Muestra 768 	p muestra: 0.56
# Muestra 769 	p muestra: 0.55
# Muestra 770 	p muestra: 0.52
# Muestra 771 	p muestra: 0.63
# Muestra 772 	p muestra: 0.58
# Muestra 773 	p muestra: 0.59
# Muestra 774 	p muestra: 0.65
# Muestra 775 	p muestra: 0.61
# Muestra 776 	p muestra: 0.61
# Muestra 777 	p muestra: 0.62
# Muestra 778 	p muestra: 0.57
# Muestra 779 	p muestra: 0.67
# Muestra 780 	p muestra: 0.53
# Muestra 781 	p muestra: 0.62
# Muestra 782 	p muestra: 0.49
# Muestra 783 	p muestra: 0.57
# Muestra 784 	p muestra: 0.63
# Muestra 785 	p muestra: 0.66
# Muestra 786 	p muestra: 0.66
# Muestra 787 	p muestra: 0.54
# Muestra 788 	p muestra: 0.60
# Muestra 789 	p muestra: 0.66
# Muestra 790 	p muestra: 0.66
# Muestra 791 	p muestra: 0.58
# Muestra 792 	p muestra: 0.54
# Muestra 793 	p muestra: 0.63
# Muestra 794 	p muestra: 0.66
# Muestra 795 	p muestra: 0.57
# Muestra 796 	p muestra: 0.61
# Muestra 797 	p muestra: 0.50
# Muestra 798 	p muestra: 0.60
# Muestra 799 	p muestra: 0.61

# %%
# Crearemos la lista de p muestral (proporciones muestrales) para después 
# graficar 

#1. Calcule la probabilidad de que la proporción de la muestra de la gente que fuma cigarrillos sea menor que 0.55.
p_barra = np.mean(muestras)
sigma_pbar = np.std(muestras)
print(f"Media de proporciones: {p_barra: 6.4f}")
print(f"sigma de proporciones: {sigma_pbar: 6.4f}")

n_muestras = np.array(muestras) <= 0.55
prob055 = sum(n_muestras)/len(muestras)
print(f"La probabilidad de que la proporción de la muestra de la gente que fuma cigarrillos sea menos que 0.55 es de : {prob055: 6.2f}")
print(10*'-----')

#2.  Visualice la distribución y el límite (0.55)

plt.hist(muestras, bins=8, density=True, label = 'Distribución') 
plt.plot([0.55, 0.55], [0, 8], 'r--', label = 'Limite')
plt.legend()
plt.xlabel('Valor variable')
plt.ylabel('Cantidad')
plt.show()
# Out:
# Media de proporciones:  0.5984
# sigma de proporciones:  0.0498
# La probabilidad de que la proporción de la muestra de la gente que fuma cigarrillos sea menos que 0.55 es de :   0.20
# --------------------------------------------------

# %% [markdown]
# <font color='green'>Fin actividad 4</font>

# %% [markdown]
# ## <font color='green'>Actividad 5</font>
#
# Un medicamento para tratar el malestar estomacal, tiene la advertencia de que algunos usuarios pueden presentar una reacción adversa a él, más aún, se piensa que alrededor del 3% de los usuarios tienen tal reacción.
#
# 1. Si una muestra aleatoria de 150 personas con malestar estomacal usa el medicamento, encuentre la probabilidad de que la proporción de la muestra de los usuarios que realmente presentan una reacción adversa, exceda el 4%.
# 2. Visualice la distribución y el límite (0.04)

# %%
# X = una persona tiene reacción adversa a medicamento para tratar el malestar estomacal (1= Si, 0=No)

# Graficando Binomial
N = 10000
n, p = 1, 0.03 # parámetros de forma 
binomial = stats.binom(n, p) # Distribución
pob2 = binomial.rvs(size=N)
plt.hist(pob2, density=True)
plt.show()

# Muestreo
# sacar m muestras de tamaño n, calcular la proporción muestral

n = 150
m = 1000
muestras = []
for i in range(m):
    muestras_n = np.random.choice(pob2, n, replace=False)
    #Ahora calculamos la proporción muestral (p muestra) de cada muestra
    muestras.append(muestras_n.mean())

for i, m in enumerate(muestras):
    print(f'Muestra {i} \tp muestra: {m:4.2f}')
# Out:
# Muestra 0 	p muestra: 0.03
# Muestra 1 	p muestra: 0.01
# Muestra 2 	p muestra: 0.02
# Muestra 3 	p muestra: 0.03
# Muestra 4 	p muestra: 0.02
# Muestra 5 	p muestra: 0.03
# Muestra 6 	p muestra: 0.00
# Muestra 7 	p muestra: 0.05
# Muestra 8 	p muestra: 0.04
# Muestra 9 	p muestra: 0.02
# Muestra 10 	p muestra: 0.05
# Muestra 11 	p muestra: 0.04
# Muestra 12 	p muestra: 0.03
# Muestra 13 	p muestra: 0.05
# Muestra 14 	p muestra: 0.01
# Muestra 15 	p muestra: 0.03
# Muestra 16 	p muestra: 0.03
# Muestra 17 	p muestra: 0.03
# Muestra 18 	p muestra: 0.03
# Muestra 19 	p muestra: 0.04
# Muestra 20 	p muestra: 0.03
# Muestra 21 	p muestra: 0.02
# Muestra 22 	p muestra: 0.03
# Muestra 23 	p muestra: 0.03
# Muestra 24 	p muestra: 0.01
# Muestra 25 	p muestra: 0.04
# Muestra 26 	p muestra: 0.03
# Muestra 27 	p muestra: 0.03
# Muestra 28 	p muestra: 0.01
# Muestra 29 	p muestra: 0.01
# Muestra 30 	p muestra: 0.03
# Muestra 31 	p muestra: 0.03
# Muestra 32 	p muestra: 0.04
# Muestra 33 	p muestra: 0.01
# Muestra 34 	p muestra: 0.04
# Muestra 35 	p muestra: 0.03
# Muestra 36 	p muestra: 0.02
# Muestra 37 	p muestra: 0.05
# Muestra 38 	p muestra: 0.03
# Muestra 39 	p muestra: 0.02
# Muestra 40 	p muestra: 0.03
# Muestra 41 	p muestra: 0.03
# Muestra 42 	p muestra: 0.03
# Muestra 43 	p muestra: 0.07
# Muestra 44 	p muestra: 0.03
# Muestra 45 	p muestra: 0.01
# Muestra 46 	p muestra: 0.03
# Muestra 47 	p muestra: 0.03
# Muestra 48 	p muestra: 0.04
# Muestra 49 	p muestra: 0.01
# Muestra 50 	p muestra: 0.02
# Muestra 51 	p muestra: 0.03
# Muestra 52 	p muestra: 0.03
# Muestra 53 	p muestra: 0.03
# Muestra 54 	p muestra: 0.05
# Muestra 55 	p muestra: 0.03
# Muestra 56 	p muestra: 0.05
# Muestra 57 	p muestra: 0.05
# Muestra 58 	p muestra: 0.01
# Muestra 59 	p muestra: 0.01
# Muestra 60 	p muestra: 0.04
# Muestra 61 	p muestra: 0.01
# Muestra 62 	p muestra: 0.02
# Muestra 63 	p muestra: 0.03
# Muestra 64 	p muestra: 0.02
# Muestra 65 	p muestra: 0.03
# Muestra 66 	p muestra: 0.05
# Muestra 67 	p muestra: 0.03
# Muestra 68 	p muestra: 0.02
# Muestra 69 	p muestra: 0.04
# Muestra 70 	p muestra: 0.02
# Muestra 71 	p muestra: 0.03
# Muestra 72 	p muestra: 0.02
# Muestra 73 	p muestra: 0.01
# Muestra 74 	p muestra: 0.03
# Muestra 75 	p muestra: 0.02
# Muestra 76 	p muestra: 0.05
# Muestra 77 	p muestra: 0.04
# Muestra 78 	p muestra: 0.01
# Muestra 79 	p muestra: 0.03
# Muestra 80 	p muestra: 0.03
# Muestra 81 	p muestra: 0.00
# Muestra 82 	p muestra: 0.04
# Muestra 83 	p muestra: 0.03
# Muestra 84 	p muestra: 0.03
# Muestra 85 	p muestra: 0.01
# Muestra 86 	p muestra: 0.01
# Muestra 87 	p muestra: 0.05
# Muestra 88 	p muestra: 0.04
# Muestra 89 	p muestra: 0.03
# Muestra 90 	p muestra: 0.04
# Muestra 91 	p muestra: 0.02
# Muestra 92 	p muestra: 0.03
# Muestra 93 	p muestra: 0.03
# Muestra 94 	p muestra: 0.06
# Muestra 95 	p muestra: 0.04
# Muestra 96 	p muestra: 0.07
# Muestra 97 	p muestra: 0.02
# Muestra 98 	p muestra: 0.02
# Muestra 99 	p muestra: 0.05
# Muestra 100 	p muestra: 0.03
# Muestra 101 	p muestra: 0.03
# Muestra 102 	p muestra: 0.03
# Muestra 103 	p muestra: 0.03
# Muestra 104 	p muestra: 0.03
# Muestra 105 	p muestra: 0.07
# Muestra 106 	p muestra: 0.01
# Muestra 107 	p muestra: 0.03
# Muestra 108 	p muestra: 0.04
# Muestra 109 	p muestra: 0.03
# Muestra 110 	p muestra: 0.01
# Muestra 111 	p muestra: 0.04
# Muestra 112 	p muestra: 0.03
# Muestra 113 	p muestra: 0.02
# Muestra 114 	p muestra: 0.01
# Muestra 115 	p muestra: 0.05
# Muestra 116 	p muestra: 0.03
# Muestra 117 	p muestra: 0.06
# Muestra 118 	p muestra: 0.04
# Muestra 119 	p muestra: 0.04
# Muestra 120 	p muestra: 0.03
# Muestra 121 	p muestra: 0.02
# Muestra 122 	p muestra: 0.02
# Muestra 123 	p muestra: 0.04
# Muestra 124 	p muestra: 0.05
# Muestra 125 	p muestra: 0.02
# Muestra 126 	p muestra: 0.02
# Muestra 127 	p muestra: 0.03
# Muestra 128 	p muestra: 0.03
# Muestra 129 	p muestra: 0.04
# Muestra 130 	p muestra: 0.03
# Muestra 131 	p muestra: 0.00
# Muestra 132 	p muestra: 0.01
# Muestra 133 	p muestra: 0.02
# Muestra 134 	p muestra: 0.03
# Muestra 135 	p muestra: 0.05
# Muestra 136 	p muestra: 0.06
# Muestra 137 	p muestra: 0.02
# Muestra 138 	p muestra: 0.03
# Muestra 139 	p muestra: 0.03
# Muestra 140 	p muestra: 0.01
# Muestra 141 	p muestra: 0.03
# Muestra 142 	p muestra: 0.02
# Muestra 143 	p muestra: 0.00
# Muestra 144 	p muestra: 0.03
# Muestra 145 	p muestra: 0.03
# Muestra 146 	p muestra: 0.03
# Muestra 147 	p muestra: 0.03
# Muestra 148 	p muestra: 0.05
# Muestra 149 	p muestra: 0.03
# Muestra 150 	p muestra: 0.04
# Muestra 151 	p muestra: 0.04
# Muestra 152 	p muestra: 0.03
# Muestra 153 	p muestra: 0.05
# Muestra 154 	p muestra: 0.05
# Muestra 155 	p muestra: 0.01
# Muestra 156 	p muestra: 0.03
# Muestra 157 	p muestra: 0.01
# Muestra 158 	p muestra: 0.03
# Muestra 159 	p muestra: 0.07
# Muestra 160 	p muestra: 0.05
# Muestra 161 	p muestra: 0.01
# Muestra 162 	p muestra: 0.04
# Muestra 163 	p muestra: 0.03
# Muestra 164 	p muestra: 0.03
# Muestra 165 	p muestra: 0.05
# Muestra 166 	p muestra: 0.03
# Muestra 167 	p muestra: 0.01
# Muestra 168 	p muestra: 0.02
# Muestra 169 	p muestra: 0.02
# Muestra 170 	p muestra: 0.07
# Muestra 171 	p muestra: 0.02
# Muestra 172 	p muestra: 0.02
# Muestra 173 	p muestra: 0.03
# Muestra 174 	p muestra: 0.09
# Muestra 175 	p muestra: 0.03
# Muestra 176 	p muestra: 0.00
# Muestra 177 	p muestra: 0.00
# Muestra 178 	p muestra: 0.04
# Muestra 179 	p muestra: 0.02
# Muestra 180 	p muestra: 0.02
# Muestra 181 	p muestra: 0.01
# Muestra 182 	p muestra: 0.04
# Muestra 183 	p muestra: 0.05
# Muestra 184 	p muestra: 0.01
# Muestra 185 	p muestra: 0.03
# Muestra 186 	p muestra: 0.05
# Muestra 187 	p muestra: 0.03
# Muestra 188 	p muestra: 0.03
# Muestra 189 	p muestra: 0.00
# Muestra 190 	p muestra: 0.02
# Muestra 191 	p muestra: 0.03
# Muestra 192 	p muestra: 0.05
# Muestra 193 	p muestra: 0.01
# Muestra 194 	p muestra: 0.04
# Muestra 195 	p muestra: 0.02
# Muestra 196 	p muestra: 0.03
# Muestra 197 	p muestra: 0.05
# Muestra 198 	p muestra: 0.04
# Muestra 199 	p muestra: 0.03
# Muestra 200 	p muestra: 0.03
# Muestra 201 	p muestra: 0.06
# Muestra 202 	p muestra: 0.06
# Muestra 203 	p muestra: 0.02
# Muestra 204 	p muestra: 0.02
# Muestra 205 	p muestra: 0.03
# Muestra 206 	p muestra: 0.03
# Muestra 207 	p muestra: 0.05
# Muestra 208 	p muestra: 0.04
# Muestra 209 	p muestra: 0.03
# Muestra 210 	p muestra: 0.05
# Muestra 211 	p muestra: 0.02
# Muestra 212 	p muestra: 0.01
# Muestra 213 	p muestra: 0.05
# Muestra 214 	p muestra: 0.06
# Muestra 215 	p muestra: 0.03
# Muestra 216 	p muestra: 0.03
# Muestra 217 	p muestra: 0.03
# Muestra 218 	p muestra: 0.04
# Muestra 219 	p muestra: 0.01
# Muestra 220 	p muestra: 0.01
# Muestra 221 	p muestra: 0.03
# Muestra 222 	p muestra: 0.04
# Muestra 223 	p muestra: 0.05
# Muestra 224 	p muestra: 0.03
# Muestra 225 	p muestra: 0.03
# Muestra 226 	p muestra: 0.03
# Muestra 227 	p muestra: 0.02
# Muestra 228 	p muestra: 0.03
# Muestra 229 	p muestra: 0.03
# Muestra 230 	p muestra: 0.03
# Muestra 231 	p muestra: 0.02
# Muestra 232 	p muestra: 0.03
# Muestra 233 	p muestra: 0.03
# Muestra 234 	p muestra: 0.05
# Muestra 235 	p muestra: 0.04
# Muestra 236 	p muestra: 0.05
# Muestra 237 	p muestra: 0.01
# Muestra 238 	p muestra: 0.05
# Muestra 239 	p muestra: 0.03
# Muestra 240 	p muestra: 0.04
# Muestra 241 	p muestra: 0.03
# Muestra 242 	p muestra: 0.02
# Muestra 243 	p muestra: 0.02
# Muestra 244 	p muestra: 0.03
# Muestra 245 	p muestra: 0.03
# Muestra 246 	p muestra: 0.02
# Muestra 247 	p muestra: 0.03
# Muestra 248 	p muestra: 0.03
# Muestra 249 	p muestra: 0.03
# Muestra 250 	p muestra: 0.06
# Muestra 251 	p muestra: 0.02
# Muestra 252 	p muestra: 0.04
# Muestra 253 	p muestra: 0.03
# Muestra 254 	p muestra: 0.06
# Muestra 255 	p muestra: 0.01
# Muestra 256 	p muestra: 0.03
# Muestra 257 	p muestra: 0.04
# Muestra 258 	p muestra: 0.02
# Muestra 259 	p muestra: 0.04
# Muestra 260 	p muestra: 0.05
# Muestra 261 	p muestra: 0.03
# Muestra 262 	p muestra: 0.03
# Muestra 263 	p muestra: 0.01
# Muestra 264 	p muestra: 0.03
# Muestra 265 	p muestra: 0.02
# Muestra 266 	p muestra: 0.02
# Muestra 267 	p muestra: 0.03
# Muestra 268 	p muestra: 0.03
# Muestra 269 	p muestra: 0.04
# Muestra 270 	p muestra: 0.03
# Muestra 271 	p muestra: 0.02
# Muestra 272 	p muestra: 0.01
# Muestra 273 	p muestra: 0.04
# Muestra 274 	p muestra: 0.05
# Muestra 275 	p muestra: 0.03
# Muestra 276 	p muestra: 0.04
# Muestra 277 	p muestra: 0.05
# Muestra 278 	p muestra: 0.00
# Muestra 279 	p muestra: 0.04
# Muestra 280 	p muestra: 0.02
# Muestra 281 	p muestra: 0.03
# Muestra 282 	p muestra: 0.03
# Muestra 283 	p muestra: 0.01
# Muestra 284 	p muestra: 0.01
# Muestra 285 	p muestra: 0.02
# Muestra 286 	p muestra: 0.02
# Muestra 287 	p muestra: 0.03
# Muestra 288 	p muestra: 0.01
# Muestra 289 	p muestra: 0.02
# Muestra 290 	p muestra: 0.02
# Muestra 291 	p muestra: 0.06
# Muestra 292 	p muestra: 0.03
# Muestra 293 	p muestra: 0.02
# Muestra 294 	p muestra: 0.05
# Muestra 295 	p muestra: 0.01
# Muestra 296 	p muestra: 0.03
# Muestra 297 	p muestra: 0.03
# Muestra 298 	p muestra: 0.03
# Muestra 299 	p muestra: 0.03
# Muestra 300 	p muestra: 0.03
# Muestra 301 	p muestra: 0.03
# Muestra 302 	p muestra: 0.02
# Muestra 303 	p muestra: 0.02
# Muestra 304 	p muestra: 0.04
# Muestra 305 	p muestra: 0.03
# Muestra 306 	p muestra: 0.03
# Muestra 307 	p muestra: 0.05
# Muestra 308 	p muestra: 0.03
# Muestra 309 	p muestra: 0.04
# Muestra 310 	p muestra: 0.05
# Muestra 311 	p muestra: 0.03
# Muestra 312 	p muestra: 0.03
# Muestra 313 	p muestra: 0.03
# Muestra 314 	p muestra: 0.04
# Muestra 315 	p muestra: 0.04
# Muestra 316 	p muestra: 0.02
# Muestra 317 	p muestra: 0.04
# Muestra 318 	p muestra: 0.02
# Muestra 319 	p muestra: 0.03
# Muestra 320 	p muestra: 0.01
# Muestra 321 	p muestra: 0.05
# Muestra 322 	p muestra: 0.03
# Muestra 323 	p muestra: 0.03
# Muestra 324 	p muestra: 0.04
# Muestra 325 	p muestra: 0.01
# Muestra 326 	p muestra: 0.03
# Muestra 327 	p muestra: 0.03
# Muestra 328 	p muestra: 0.00
# Muestra 329 	p muestra: 0.04
# Muestra 330 	p muestra: 0.01
# Muestra 331 	p muestra: 0.07
# Muestra 332 	p muestra: 0.03
# Muestra 333 	p muestra: 0.02
# Muestra 334 	p muestra: 0.02
# Muestra 335 	p muestra: 0.04
# Muestra 336 	p muestra: 0.05
# Muestra 337 	p muestra: 0.03
# Muestra 338 	p muestra: 0.01
# Muestra 339 	p muestra: 0.01
# Muestra 340 	p muestra: 0.06
# Muestra 341 	p muestra: 0.06
# Muestra 342 	p muestra: 0.03
# Muestra 343 	p muestra: 0.02
# Muestra 344 	p muestra: 0.01
# Muestra 345 	p muestra: 0.05
# Muestra 346 	p muestra: 0.02
# Muestra 347 	p muestra: 0.02
# Muestra 348 	p muestra: 0.01
# Muestra 349 	p muestra: 0.03
# Muestra 350 	p muestra: 0.01
# Muestra 351 	p muestra: 0.03
# Muestra 352 	p muestra: 0.06
# Muestra 353 	p muestra: 0.01
# Muestra 354 	p muestra: 0.03
# Muestra 355 	p muestra: 0.05
# Muestra 356 	p muestra: 0.05
# Muestra 357 	p muestra: 0.04
# Muestra 358 	p muestra: 0.07
# Muestra 359 	p muestra: 0.04
# Muestra 360 	p muestra: 0.02
# Muestra 361 	p muestra: 0.02
# Muestra 362 	p muestra: 0.05
# Muestra 363 	p muestra: 0.03
# Muestra 364 	p muestra: 0.04
# Muestra 365 	p muestra: 0.03
# Muestra 366 	p muestra: 0.03
# Muestra 367 	p muestra: 0.02
# Muestra 368 	p muestra: 0.01
# Muestra 369 	p muestra: 0.05
# Muestra 370 	p muestra: 0.05
# Muestra 371 	p muestra: 0.03
# Muestra 372 	p muestra: 0.03
# Muestra 373 	p muestra: 0.03
# Muestra 374 	p muestra: 0.04
# Muestra 375 	p muestra: 0.03
# Muestra 376 	p muestra: 0.03
# Muestra 377 	p muestra: 0.01
# Muestra 378 	p muestra: 0.03
# Muestra 379 	p muestra: 0.02
# Muestra 380 	p muestra: 0.03
# Muestra 381 	p muestra: 0.03
# Muestra 382 	p muestra: 0.03
# Muestra 383 	p muestra: 0.02
# Muestra 384 	p muestra: 0.04
# Muestra 385 	p muestra: 0.02
# Muestra 386 	p muestra: 0.04
# Muestra 387 	p muestra: 0.05
# Muestra 388 	p muestra: 0.04
# Muestra 389 	p muestra: 0.03
# Muestra 390 	p muestra: 0.04
# Muestra 391 	p muestra: 0.05
# Muestra 392 	p muestra: 0.02
# Muestra 393 	p muestra: 0.01
# Muestra 394 	p muestra: 0.01
# Muestra 395 	p muestra: 0.03
# Muestra 396 	p muestra: 0.03
# Muestra 397 	p muestra: 0.04
# Muestra 398 	p muestra: 0.01
# Muestra 399 	p muestra: 0.02
# Muestra 400 	p muestra: 0.04
# Muestra 401 	p muestra: 0.03
# Muestra 402 	p muestra: 0.04
# Muestra 403 	p muestra: 0.03
# Muestra 404 	p muestra: 0.05
# Muestra 405 	p muestra: 0.03
# Muestra 406 	p muestra: 0.03
# Muestra 407 	p muestra: 0.05
# Muestra 408 	p muestra: 0.01
# Muestra 409 	p muestra: 0.03
# Muestra 410 	p muestra: 0.03
# Muestra 411 	p muestra: 0.05
# Muestra 412 	p muestra: 0.04
# Muestra 413 	p muestra: 0.03
# Muestra 414 	p muestra: 0.07
# Muestra 415 	p muestra: 0.04
# Muestra 416 	p muestra: 0.03
# Muestra 417 	p muestra: 0.01
# Muestra 418 	p muestra: 0.03
# Muestra 419 	p muestra: 0.03
# Muestra 420 	p muestra: 0.03
# Muestra 421 	p muestra: 0.03
# Muestra 422 	p muestra: 0.04
# Muestra 423 	p muestra: 0.01
# Muestra 424 	p muestra: 0.02
# Muestra 425 	p muestra: 0.03
# Muestra 426 	p muestra: 0.03
# Muestra 427 	p muestra: 0.01
# Muestra 428 	p muestra: 0.03
# Muestra 429 	p muestra: 0.01
# Muestra 430 	p muestra: 0.02
# Muestra 431 	p muestra: 0.01
# Muestra 432 	p muestra: 0.03
# Muestra 433 	p muestra: 0.01
# Muestra 434 	p muestra: 0.02
# Muestra 435 	p muestra: 0.06
# Muestra 436 	p muestra: 0.05
# Muestra 437 	p muestra: 0.05
# Muestra 438 	p muestra: 0.01
# Muestra 439 	p muestra: 0.03
# Muestra 440 	p muestra: 0.03
# Muestra 441 	p muestra: 0.03
# Muestra 442 	p muestra: 0.02
# Muestra 443 	p muestra: 0.07
# Muestra 444 	p muestra: 0.05
# Muestra 445 	p muestra: 0.03
# Muestra 446 	p muestra: 0.02
# Muestra 447 	p muestra: 0.02
# Muestra 448 	p muestra: 0.02
# Muestra 449 	p muestra: 0.01
# Muestra 450 	p muestra: 0.04
# Muestra 451 	p muestra: 0.03
# Muestra 452 	p muestra: 0.02
# Muestra 453 	p muestra: 0.06
# Muestra 454 	p muestra: 0.03
# Muestra 455 	p muestra: 0.03
# Muestra 456 	p muestra: 0.03
# Muestra 457 	p muestra: 0.04
# Muestra 458 	p muestra: 0.03
# Muestra 459 	p muestra: 0.03
# Muestra 460 	p muestra: 0.03
# Muestra 461 	p muestra: 0.03
# Muestra 462 	p muestra: 0.03
# Muestra 463 	p muestra: 0.05
# Muestra 464 	p muestra: 0.05
# Muestra 465 	p muestra: 0.06
# Muestra 466 	p muestra: 0.01
# Muestra 467 	p muestra: 0.04
# Muestra 468 	p muestra: 0.02
# Muestra 469 	p muestra: 0.03
# Muestra 470 	p muestra: 0.03
# Muestra 471 	p muestra: 0.02
# Muestra 472 	p muestra: 0.06
# Muestra 473 	p muestra: 0.03
# Muestra 474 	p muestra: 0.03
# Muestra 475 	p muestra: 0.05
# Muestra 476 	p muestra: 0.04
# Muestra 477 	p muestra: 0.03
# Muestra 478 	p muestra: 0.04
# Muestra 479 	p muestra: 0.02
# Muestra 480 	p muestra: 0.03
# Muestra 481 	p muestra: 0.03
# Muestra 482 	p muestra: 0.03
# Muestra 483 	p muestra: 0.01
# Muestra 484 	p muestra: 0.01
# Muestra 485 	p muestra: 0.05
# Muestra 486 	p muestra: 0.04
# Muestra 487 	p muestra: 0.02
# Muestra 488 	p muestra: 0.02
# Muestra 489 	p muestra: 0.03
# Muestra 490 	p muestra: 0.03
# Muestra 491 	p muestra: 0.05
# Muestra 492 	p muestra: 0.03
# Muestra 493 	p muestra: 0.03
# Muestra 494 	p muestra: 0.03
# Muestra 495 	p muestra: 0.04
# Muestra 496 	p muestra: 0.03
# Muestra 497 	p muestra: 0.05
# Muestra 498 	p muestra: 0.05
# Muestra 499 	p muestra: 0.04
# Muestra 500 	p muestra: 0.01
# Muestra 501 	p muestra: 0.03
# Muestra 502 	p muestra: 0.03
# Muestra 503 	p muestra: 0.03
# Muestra 504 	p muestra: 0.05
# Muestra 505 	p muestra: 0.01
# Muestra 506 	p muestra: 0.03
# Muestra 507 	p muestra: 0.04
# Muestra 508 	p muestra: 0.03
# Muestra 509 	p muestra: 0.03
# Muestra 510 	p muestra: 0.04
# Muestra 511 	p muestra: 0.02
# Muestra 512 	p muestra: 0.03
# Muestra 513 	p muestra: 0.02
# Muestra 514 	p muestra: 0.04
# Muestra 515 	p muestra: 0.01
# Muestra 516 	p muestra: 0.02
# Muestra 517 	p muestra: 0.06
# Muestra 518 	p muestra: 0.05
# Muestra 519 	p muestra: 0.03
# Muestra 520 	p muestra: 0.04
# Muestra 521 	p muestra: 0.04
# Muestra 522 	p muestra: 0.03
# Muestra 523 	p muestra: 0.03
# Muestra 524 	p muestra: 0.03
# Muestra 525 	p muestra: 0.02
# Muestra 526 	p muestra: 0.00
# Muestra 527 	p muestra: 0.04
# Muestra 528 	p muestra: 0.03
# Muestra 529 	p muestra: 0.03
# Muestra 530 	p muestra: 0.05
# Muestra 531 	p muestra: 0.03
# Muestra 532 	p muestra: 0.01
# Muestra 533 	p muestra: 0.01
# Muestra 534 	p muestra: 0.03
# Muestra 535 	p muestra: 0.02
# Muestra 536 	p muestra: 0.01
# Muestra 537 	p muestra: 0.03
# Muestra 538 	p muestra: 0.03
# Muestra 539 	p muestra: 0.04
# Muestra 540 	p muestra: 0.03
# Muestra 541 	p muestra: 0.03
# Muestra 542 	p muestra: 0.01
# Muestra 543 	p muestra: 0.01
# Muestra 544 	p muestra: 0.01
# Muestra 545 	p muestra: 0.02
# Muestra 546 	p muestra: 0.03
# Muestra 547 	p muestra: 0.03
# Muestra 548 	p muestra: 0.02
# Muestra 549 	p muestra: 0.03
# Muestra 550 	p muestra: 0.04
# Muestra 551 	p muestra: 0.01
# Muestra 552 	p muestra: 0.03
# Muestra 553 	p muestra: 0.03
# Muestra 554 	p muestra: 0.03
# Muestra 555 	p muestra: 0.02
# Muestra 556 	p muestra: 0.04
# Muestra 557 	p muestra: 0.03
# Muestra 558 	p muestra: 0.03
# Muestra 559 	p muestra: 0.03
# Muestra 560 	p muestra: 0.02
# Muestra 561 	p muestra: 0.01
# Muestra 562 	p muestra: 0.03
# Muestra 563 	p muestra: 0.04
# Muestra 564 	p muestra: 0.03
# Muestra 565 	p muestra: 0.05
# Muestra 566 	p muestra: 0.05
# Muestra 567 	p muestra: 0.07
# Muestra 568 	p muestra: 0.05
# Muestra 569 	p muestra: 0.02
# Muestra 570 	p muestra: 0.05
# Muestra 571 	p muestra: 0.03
# Muestra 572 	p muestra: 0.03
# Muestra 573 	p muestra: 0.05
# Muestra 574 	p muestra: 0.03
# Muestra 575 	p muestra: 0.04
# Muestra 576 	p muestra: 0.03
# Muestra 577 	p muestra: 0.01
# Muestra 578 	p muestra: 0.03
# Muestra 579 	p muestra: 0.01
# Muestra 580 	p muestra: 0.01
# Muestra 581 	p muestra: 0.03
# Muestra 582 	p muestra: 0.06
# Muestra 583 	p muestra: 0.03
# Muestra 584 	p muestra: 0.03
# Muestra 585 	p muestra: 0.05
# Muestra 586 	p muestra: 0.03
# Muestra 587 	p muestra: 0.01
# Muestra 588 	p muestra: 0.02
# Muestra 589 	p muestra: 0.01
# Muestra 590 	p muestra: 0.03
# Muestra 591 	p muestra: 0.01
# Muestra 592 	p muestra: 0.03
# Muestra 593 	p muestra: 0.04
# Muestra 594 	p muestra: 0.03
# Muestra 595 	p muestra: 0.04
# Muestra 596 	p muestra: 0.02
# Muestra 597 	p muestra: 0.01
# Muestra 598 	p muestra: 0.03
# Muestra 599 	p muestra: 0.02
# Muestra 600 	p muestra: 0.05
# Muestra 601 	p muestra: 0.04
# Muestra 602 	p muestra: 0.03
# Muestra 603 	p muestra: 0.03
# Muestra 604 	p muestra: 0.01
# Muestra 605 	p muestra: 0.01
# Muestra 606 	p muestra: 0.03
# Muestra 607 	p muestra: 0.03
# Muestra 608 	p muestra: 0.01
# Muestra 609 	p muestra: 0.01
# Muestra 610 	p muestra: 0.04
# Muestra 611 	p muestra: 0.05
# Muestra 612 	p muestra: 0.03
# Muestra 613 	p muestra: 0.03
# Muestra 614 	p muestra: 0.05
# Muestra 615 	p muestra: 0.01
# Muestra 616 	p muestra: 0.03
# Muestra 617 	p muestra: 0.05
# Muestra 618 	p muestra: 0.03
# Muestra 619 	p muestra: 0.02
# Muestra 620 	p muestra: 0.04
# Muestra 621 	p muestra: 0.01
# Muestra 622 	p muestra: 0.03
# Muestra 623 	p muestra: 0.02
# Muestra 624 	p muestra: 0.01
# Muestra 625 	p muestra: 0.04
# Muestra 626 	p muestra: 0.05
# Muestra 627 	p muestra: 0.04
# Muestra 628 	p muestra: 0.04
# Muestra 629 	p muestra: 0.04
# Muestra 630 	p muestra: 0.05
# Muestra 631 	p muestra: 0.05
# Muestra 632 	p muestra: 0.03
# Muestra 633 	p muestra: 0.04
# Muestra 634 	p muestra: 0.03
# Muestra 635 	p muestra: 0.01
# Muestra 636 	p muestra: 0.01
# Muestra 637 	p muestra: 0.03
# Muestra 638 	p muestra: 0.03
# Muestra 639 	p muestra: 0.05
# Muestra 640 	p muestra: 0.05
# Muestra 641 	p muestra: 0.03
# Muestra 642 	p muestra: 0.03
# Muestra 643 	p muestra: 0.02
# Muestra 644 	p muestra: 0.01
# Muestra 645 	p muestra: 0.04
# Muestra 646 	p muestra: 0.06
# Muestra 647 	p muestra: 0.03
# Muestra 648 	p muestra: 0.03
# Muestra 649 	p muestra: 0.02
# Muestra 650 	p muestra: 0.07
# Muestra 651 	p muestra: 0.01
# Muestra 652 	p muestra: 0.03
# Muestra 653 	p muestra: 0.02
# Muestra 654 	p muestra: 0.01
# Muestra 655 	p muestra: 0.02
# Muestra 656 	p muestra: 0.09
# Muestra 657 	p muestra: 0.05
# Muestra 658 	p muestra: 0.05
# Muestra 659 	p muestra: 0.01
# Muestra 660 	p muestra: 0.01
# Muestra 661 	p muestra: 0.01
# Muestra 662 	p muestra: 0.01
# Muestra 663 	p muestra: 0.02
# Muestra 664 	p muestra: 0.04
# Muestra 665 	p muestra: 0.03
# Muestra 666 	p muestra: 0.02
# Muestra 667 	p muestra: 0.01
# Muestra 668 	p muestra: 0.01
# Muestra 669 	p muestra: 0.03
# Muestra 670 	p muestra: 0.01
# Muestra 671 	p muestra: 0.00
# Muestra 672 	p muestra: 0.02
# Muestra 673 	p muestra: 0.03
# Muestra 674 	p muestra: 0.04
# Muestra 675 	p muestra: 0.03
# Muestra 676 	p muestra: 0.01
# Muestra 677 	p muestra: 0.02
# Muestra 678 	p muestra: 0.03
# Muestra 679 	p muestra: 0.05
# Muestra 680 	p muestra: 0.01
# Muestra 681 	p muestra: 0.03
# Muestra 682 	p muestra: 0.03
# Muestra 683 	p muestra: 0.05
# Muestra 684 	p muestra: 0.03
# Muestra 685 	p muestra: 0.03
# Muestra 686 	p muestra: 0.03
# Muestra 687 	p muestra: 0.04
# Muestra 688 	p muestra: 0.03
# Muestra 689 	p muestra: 0.02
# Muestra 690 	p muestra: 0.03
# Muestra 691 	p muestra: 0.05
# Muestra 692 	p muestra: 0.04
# Muestra 693 	p muestra: 0.03
# Muestra 694 	p muestra: 0.04
# Muestra 695 	p muestra: 0.01
# Muestra 696 	p muestra: 0.02
# Muestra 697 	p muestra: 0.05
# Muestra 698 	p muestra: 0.03
# Muestra 699 	p muestra: 0.02
# Muestra 700 	p muestra: 0.03
# Muestra 701 	p muestra: 0.02
# Muestra 702 	p muestra: 0.02
# Muestra 703 	p muestra: 0.01
# Muestra 704 	p muestra: 0.03
# Muestra 705 	p muestra: 0.03
# Muestra 706 	p muestra: 0.05
# Muestra 707 	p muestra: 0.01
# Muestra 708 	p muestra: 0.05
# Muestra 709 	p muestra: 0.03
# Muestra 710 	p muestra: 0.01
# Muestra 711 	p muestra: 0.03
# Muestra 712 	p muestra: 0.01
# Muestra 713 	p muestra: 0.03
# Muestra 714 	p muestra: 0.02
# Muestra 715 	p muestra: 0.04
# Muestra 716 	p muestra: 0.05
# Muestra 717 	p muestra: 0.02
# Muestra 718 	p muestra: 0.02
# Muestra 719 	p muestra: 0.01
# Muestra 720 	p muestra: 0.06
# Muestra 721 	p muestra: 0.04
# Muestra 722 	p muestra: 0.02
# Muestra 723 	p muestra: 0.02
# Muestra 724 	p muestra: 0.01
# Muestra 725 	p muestra: 0.03
# Muestra 726 	p muestra: 0.01
# Muestra 727 	p muestra: 0.02
# Muestra 728 	p muestra: 0.05
# Muestra 729 	p muestra: 0.03
# Muestra 730 	p muestra: 0.03
# Muestra 731 	p muestra: 0.05
# Muestra 732 	p muestra: 0.03
# Muestra 733 	p muestra: 0.06
# Muestra 734 	p muestra: 0.05
# Muestra 735 	p muestra: 0.04
# Muestra 736 	p muestra: 0.04
# Muestra 737 	p muestra: 0.03
# Muestra 738 	p muestra: 0.03
# Muestra 739 	p muestra: 0.03
# Muestra 740 	p muestra: 0.02
# Muestra 741 	p muestra: 0.04
# Muestra 742 	p muestra: 0.03
# Muestra 743 	p muestra: 0.02
# Muestra 744 	p muestra: 0.02
# Muestra 745 	p muestra: 0.04
# Muestra 746 	p muestra: 0.03
# Muestra 747 	p muestra: 0.01
# Muestra 748 	p muestra: 0.02
# Muestra 749 	p muestra: 0.03
# Muestra 750 	p muestra: 0.04
# Muestra 751 	p muestra: 0.03
# Muestra 752 	p muestra: 0.03
# Muestra 753 	p muestra: 0.04
# Muestra 754 	p muestra: 0.04
# Muestra 755 	p muestra: 0.02
# Muestra 756 	p muestra: 0.05
# Muestra 757 	p muestra: 0.01
# Muestra 758 	p muestra: 0.03
# Muestra 759 	p muestra: 0.03
# Muestra 760 	p muestra: 0.03
# Muestra 761 	p muestra: 0.05
# Muestra 762 	p muestra: 0.02
# Muestra 763 	p muestra: 0.04
# Muestra 764 	p muestra: 0.02
# Muestra 765 	p muestra: 0.02
# Muestra 766 	p muestra: 0.02
# Muestra 767 	p muestra: 0.01
# Muestra 768 	p muestra: 0.03
# Muestra 769 	p muestra: 0.05
# Muestra 770 	p muestra: 0.01
# Muestra 771 	p muestra: 0.06
# Muestra 772 	p muestra: 0.03
# Muestra 773 	p muestra: 0.03
# Muestra 774 	p muestra: 0.04
# Muestra 775 	p muestra: 0.03
# Muestra 776 	p muestra: 0.02
# Muestra 777 	p muestra: 0.03
# Muestra 778 	p muestra: 0.02
# Muestra 779 	p muestra: 0.04
# Muestra 780 	p muestra: 0.05
# Muestra 781 	p muestra: 0.05
# Muestra 782 	p muestra: 0.01
# Muestra 783 	p muestra: 0.04
# Muestra 784 	p muestra: 0.01
# Muestra 785 	p muestra: 0.03
# Muestra 786 	p muestra: 0.03
# Muestra 787 	p muestra: 0.04
# Muestra 788 	p muestra: 0.02
# Muestra 789 	p muestra: 0.03
# Muestra 790 	p muestra: 0.04
# Muestra 791 	p muestra: 0.03
# Muestra 792 	p muestra: 0.03
# Muestra 793 	p muestra: 0.04
# Muestra 794 	p muestra: 0.03
# Muestra 795 	p muestra: 0.05
# Muestra 796 	p muestra: 0.01
# Muestra 797 	p muestra: 0.06
# Muestra 798 	p muestra: 0.03
# Muestra 799 	p muestra: 0.04
# Muestra 800 	p muestra: 0.06
# Muestra 801 	p muestra: 0.03
# Muestra 802 	p muestra: 0.02
# Muestra 803 	p muestra: 0.02
# Muestra 804 	p muestra: 0.04
# Muestra 805 	p muestra: 0.02
# Muestra 806 	p muestra: 0.01
# Muestra 807 	p muestra: 0.03
# Muestra 808 	p muestra: 0.04
# Muestra 809 	p muestra: 0.02
# Muestra 810 	p muestra: 0.02
# Muestra 811 	p muestra: 0.04
# Muestra 812 	p muestra: 0.02
# Muestra 813 	p muestra: 0.03
# Muestra 814 	p muestra: 0.02
# Muestra 815 	p muestra: 0.03
# Muestra 816 	p muestra: 0.04
# Muestra 817 	p muestra: 0.02
# Muestra 818 	p muestra: 0.02
# Muestra 819 	p muestra: 0.03
# Muestra 820 	p muestra: 0.05
# Muestra 821 	p muestra: 0.02
# Muestra 822 	p muestra: 0.01
# Muestra 823 	p muestra: 0.01
# Muestra 824 	p muestra: 0.03
# Muestra 825 	p muestra: 0.01
# Muestra 826 	p muestra: 0.04
# Muestra 827 	p muestra: 0.04
# Muestra 828 	p muestra: 0.03
# Muestra 829 	p muestra: 0.01
# Muestra 830 	p muestra: 0.03
# Muestra 831 	p muestra: 0.04
# Muestra 832 	p muestra: 0.03
# Muestra 833 	p muestra: 0.04
# Muestra 834 	p muestra: 0.02
# Muestra 835 	p muestra: 0.03
# Muestra 836 	p muestra: 0.01
# Muestra 837 	p muestra: 0.02
# Muestra 838 	p muestra: 0.02
# Muestra 839 	p muestra: 0.02
# Muestra 840 	p muestra: 0.03
# Muestra 841 	p muestra: 0.02
# Muestra 842 	p muestra: 0.03
# Muestra 843 	p muestra: 0.03
# Muestra 844 	p muestra: 0.05
# Muestra 845 	p muestra: 0.03
# Muestra 846 	p muestra: 0.05
# Muestra 847 	p muestra: 0.03
# Muestra 848 	p muestra: 0.03
# Muestra 849 	p muestra: 0.05
# Muestra 850 	p muestra: 0.03
# Muestra 851 	p muestra: 0.03
# Muestra 852 	p muestra: 0.03
# Muestra 853 	p muestra: 0.03
# Muestra 854 	p muestra: 0.04
# Muestra 855 	p muestra: 0.02
# Muestra 856 	p muestra: 0.03
# Muestra 857 	p muestra: 0.05
# Muestra 858 	p muestra: 0.05
# Muestra 859 	p muestra: 0.01
# Muestra 860 	p muestra: 0.01
# Muestra 861 	p muestra: 0.03
# Muestra 862 	p muestra: 0.04
# Muestra 863 	p muestra: 0.02
# Muestra 864 	p muestra: 0.03
# Muestra 865 	p muestra: 0.03
# Muestra 866 	p muestra: 0.03
# Muestra 867 	p muestra: 0.01
# Muestra 868 	p muestra: 0.04
# Muestra 869 	p muestra: 0.02
# Muestra 870 	p muestra: 0.04
# Muestra 871 	p muestra: 0.02
# Muestra 872 	p muestra: 0.03
# Muestra 873 	p muestra: 0.02
# Muestra 874 	p muestra: 0.04
# Muestra 875 	p muestra: 0.03
# Muestra 876 	p muestra: 0.03
# Muestra 877 	p muestra: 0.01
# Muestra 878 	p muestra: 0.03
# Muestra 879 	p muestra: 0.01
# Muestra 880 	p muestra: 0.03
# Muestra 881 	p muestra: 0.03
# Muestra 882 	p muestra: 0.02
# Muestra 883 	p muestra: 0.01
# Muestra 884 	p muestra: 0.01
# Muestra 885 	p muestra: 0.03
# Muestra 886 	p muestra: 0.02
# Muestra 887 	p muestra: 0.03
# Muestra 888 	p muestra: 0.03
# Muestra 889 	p muestra: 0.01
# Muestra 890 	p muestra: 0.02
# Muestra 891 	p muestra: 0.04
# Muestra 892 	p muestra: 0.03
# Muestra 893 	p muestra: 0.03
# Muestra 894 	p muestra: 0.01
# Muestra 895 	p muestra: 0.05
# Muestra 896 	p muestra: 0.04
# Muestra 897 	p muestra: 0.01
# Muestra 898 	p muestra: 0.02
# Muestra 899 	p muestra: 0.02
# Muestra 900 	p muestra: 0.04
# Muestra 901 	p muestra: 0.04
# Muestra 902 	p muestra: 0.05
# Muestra 903 	p muestra: 0.01
# Muestra 904 	p muestra: 0.03
# Muestra 905 	p muestra: 0.03
# Muestra 906 	p muestra: 0.06
# Muestra 907 	p muestra: 0.04
# Muestra 908 	p muestra: 0.03
# Muestra 909 	p muestra: 0.02
# Muestra 910 	p muestra: 0.03
# Muestra 911 	p muestra: 0.04
# Muestra 912 	p muestra: 0.04
# Muestra 913 	p muestra: 0.02
# Muestra 914 	p muestra: 0.05
# Muestra 915 	p muestra: 0.05
# Muestra 916 	p muestra: 0.00
# Muestra 917 	p muestra: 0.01
# Muestra 918 	p muestra: 0.01
# Muestra 919 	p muestra: 0.06
# Muestra 920 	p muestra: 0.03
# Muestra 921 	p muestra: 0.01
# Muestra 922 	p muestra: 0.05
# Muestra 923 	p muestra: 0.02
# Muestra 924 	p muestra: 0.03
# Muestra 925 	p muestra: 0.03
# Muestra 926 	p muestra: 0.02
# Muestra 927 	p muestra: 0.03
# Muestra 928 	p muestra: 0.04
# Muestra 929 	p muestra: 0.04
# Muestra 930 	p muestra: 0.04
# Muestra 931 	p muestra: 0.02
# Muestra 932 	p muestra: 0.03
# Muestra 933 	p muestra: 0.02
# Muestra 934 	p muestra: 0.02
# Muestra 935 	p muestra: 0.01
# Muestra 936 	p muestra: 0.03
# Muestra 937 	p muestra: 0.02
# Muestra 938 	p muestra: 0.02
# Muestra 939 	p muestra: 0.03
# Muestra 940 	p muestra: 0.05
# Muestra 941 	p muestra: 0.03
# Muestra 942 	p muestra: 0.01
# Muestra 943 	p muestra: 0.05
# Muestra 944 	p muestra: 0.04
# Muestra 945 	p muestra: 0.03
# Muestra 946 	p muestra: 0.03
# Muestra 947 	p muestra: 0.03
# Muestra 948 	p muestra: 0.03
# Muestra 949 	p muestra: 0.01
# Muestra 950 	p muestra: 0.01
# Muestra 951 	p muestra: 0.06
# Muestra 952 	p muestra: 0.03
# Muestra 953 	p muestra: 0.05
# Muestra 954 	p muestra: 0.03
# Muestra 955 	p muestra: 0.03
# Muestra 956 	p muestra: 0.01
# Muestra 957 	p muestra: 0.03
# Muestra 958 	p muestra: 0.03
# Muestra 959 	p muestra: 0.05
# Muestra 960 	p muestra: 0.04
# Muestra 961 	p muestra: 0.01
# Muestra 962 	p muestra: 0.03
# Muestra 963 	p muestra: 0.03
# Muestra 964 	p muestra: 0.04
# Muestra 965 	p muestra: 0.04
# Muestra 966 	p muestra: 0.01
# Muestra 967 	p muestra: 0.05
# Muestra 968 	p muestra: 0.03
# Muestra 969 	p muestra: 0.03
# Muestra 970 	p muestra: 0.01
# Muestra 971 	p muestra: 0.05
# Muestra 972 	p muestra: 0.04
# Muestra 973 	p muestra: 0.01
# Muestra 974 	p muestra: 0.04
# Muestra 975 	p muestra: 0.03
# Muestra 976 	p muestra: 0.03
# Muestra 977 	p muestra: 0.04
# Muestra 978 	p muestra: 0.01
# Muestra 979 	p muestra: 0.05
# Muestra 980 	p muestra: 0.05
# Muestra 981 	p muestra: 0.03
# Muestra 982 	p muestra: 0.05
# Muestra 983 	p muestra: 0.02
# Muestra 984 	p muestra: 0.03
# Muestra 985 	p muestra: 0.01
# Muestra 986 	p muestra: 0.01
# Muestra 987 	p muestra: 0.03
# Muestra 988 	p muestra: 0.01
# Muestra 989 	p muestra: 0.05
# Muestra 990 	p muestra: 0.03
# Muestra 991 	p muestra: 0.05
# Muestra 992 	p muestra: 0.02
# Muestra 993 	p muestra: 0.03
# Muestra 994 	p muestra: 0.04
# Muestra 995 	p muestra: 0.04
# Muestra 996 	p muestra: 0.03
# Muestra 997 	p muestra: 0.03
# Muestra 998 	p muestra: 0.03
# Muestra 999 	p muestra: 0.02

# %%
# Crearemos la lista de p muestral (proporciones muestrales) para después 
# graficar 

#1. Si una muestra aleatoria de 150 personas con malestar estomacal usa el medicamento, 
# encuentre la probabilidad de que la proporción de la muestra de los usuarios que realmente presentan una reacción adversa, exceda el 4%.

p_barra = np.mean(muestras)
sigma_pbar = np.std(muestras)
print(f"Media de proporciones: {p_barra: 6.4f}")
print(f"sigma de proporciones: {sigma_pbar: 6.4f}")

n_muestras = np.array(muestras) >= 0.04
prob004 = sum(n_muestras)/len(muestras)
print(f"La probabilidad de que la proporción de la muestra de los usuarios que realmente presentan una reacción adversa, exceda el 4% es de : {prob004: 6.2f}")
print(10*'-----')

#2.  Visualice la distribución y el límite (0.04)

plt.hist(muestras, bins=8, density=True, label = 'Distribución') 
plt.plot([0.04, 0.04], [0, 32], 'r--', label = 'Limite')
plt.legend()
plt.xlabel('Valor variable')
plt.ylabel('Cantidad')
plt.show()
# Out:
# Media de proporciones:  0.0302
# sigma de proporciones:  0.0138
# La probabilidad de que la proporción de la muestra de los usuarios que realmente presentan una reacción adversa, exceda el 4% es de :   0.30
# --------------------------------------------------

# %% [markdown]
# <font color='green'>Fin actividad 5</font>

# %% [markdown]
# ## <font color='blue'>Estimación con Intervalos de Confianza</font>
# ### Qué es un intervalo de confianza?
# Un __intervalo de confianza__ es un rango de valores, derivado de los estadísticos de la muestra, que __posiblemente incluya el valor de un parámetro de población desconocido__. Debido a su naturaleza aleatoria, es poco probable que dos muestras de una población en particular produzcan intervalos de confianza idénticos. Sin embargo, si usted repitiera muchas veces su muestra, un determinado porcentaje de los intervalos de confianza resultantes incluiría el parámetro de población desconocido.
#
#
# <img src='https://drive.google.com/uc?export=view&id=1fQwJrU0nnCImpZ48g1uj17lPNAqXuvpc' width="300" style="margin-right: 20px">
# <br>
# En este caso, la línea negra horizontal representa el valor fijo de la media desconocida de la población, $\mu$. Los intervalos de confianza azules verticales que se sobreponen a la línea horizontal contienen el valor de la media de la población. El intervalo de confianza rojo que está completamente por debajo de la línea horizontal no lo contiene. Un intervalo de confianza de 95% indica que 19 de 20 muestras (95%) de la misma población producirán intervalos de confianza que contendrán el parámetro de población.
#
# Si los valores de los parámetros son desconocidos, podemos estimarlos en base a muestras y esperamos que sean una buena aproximación al valor exacto.
#
#
# <img src='https://drive.google.com/uc?export=view&id=1bvC2Hjve00X6DIISBvfUuYfv0WrOjsZ5' width="500" align="left" style="margin-right: 20px">
# <br>

# %% [markdown]
# Para que las estimaciones sean confiables se debe cumplir:
#
# *   Muestreo aleatorio probabilístico
# *   La variable X debe distribuirse Normal, en caso contrario, el tamaño de la muestra debe ser lo suficientemente grande.
# *   Desviación estándar conocida (o estimada a partir de una muestra con $n \gt 30$)

# %% [markdown]
# ### Estimación por Intervalos
#
# <img src='https://drive.google.com/uc?export=view&id=1uwfK8KLCHcVKjGQZE6uaijcGJCC-15KE' width="500" style="margin-right: 20px">
# <br>
#
# Recordemos que la __estimación puntual__ entrega un “número”; el valor de una característica de la población (e.g.: la media, proporción, etc.). En muchos casos, esta estimación puntual no es suficiente en el sentido de que no indica el error que se comete en dicho cálculo.
#
# Se aconseja junto a la estimación puntual del parámetro, entregar un __intervalo numérico__ que mida el __margen de error__ que, de acuerdo a las observaciones muestrales, pueda tener dicha estimación.
#
# Ejemplo de intervalo para la media poblacional:
#
# $$ \bar{x} - EM \lt \mu \lt \bar{x} + EM$$
#
# Donde $\bar{x}$ es el estimador puntual de la media poblacional $\mu$, y $EM$ es el __margen del error__ de dicha estimación.

# %% [markdown]
# ### Intervalo de Confianza para la Media Poblacional
#
# El intervalo de confianza permite estimar con una cierta probabilidad entre qué rango de valores se encuentra el parámetro.
#
# $$P(LI \lt \mu \lt LS) = 1 - \alpha$$
#
# *  __Nivel de confianza__:  es la probabilidad de que el parámetro (poblacional) esté dentro del intervalo de confianza. Se representa por $(1 - \alpha)$, y sus valores habituales son 95% y 99%.
#
# *  __Nivel de significación o de riesgo__: se denomina como $\alpha$, y corresponde a la probabilidad de que el parámetro poblacional no pertenezca al intervalo de confianza.
#
# *  __Margen de error__: es la diferencia entre el extremo superior y el extremo inferior del intervalo de confianza:  $LS - LI$.
#
# *  __Error muestral (EM)__: es la semi amplitud del intervalo de confianza (la mitad del margen del error): $(LS - LI)/2$

# %% [markdown]
# ### Muestras grandes
# **Pasos**
#
# Sea $\bar{x}$  una variable aleatoria (v.a.) que se distribuye Normal $\Rightarrow \bar{x} \sim N(\mu, \frac{\sigma}{\sqrt{n}})$ con $\sigma$ conocida.
#
# 1.  Fijar el nivel de confianza, $(1-\alpha);\quad 0 \lt \alpha \lt 1$
# 2.  Selección el estadístico pivote ($Z$) para la estimar la media muestral:
#
# $$Z = \frac{\bar{x} - \mu}{\frac{\sigma}{\sqrt{n}}} \sim N(0,1)$$

# %% [markdown]
# 3.  Plantear el Intervalo de Confianza para $\mu$ con nivel de confianza $(1−\alpha)$:
#
# $$
# IC_{1-\alpha}(\mu) = \left(\bar{x} - Z_{1-\alpha/2}\frac{\sigma}{\sqrt{n}};\quad\bar{x} + Z_{1-\alpha/2}\frac{\sigma}{\sqrt{n}}\right)
# $$
#
# donde:
# $$
# EM = Z_{1-\alpha/2}\frac{\sigma}{\sqrt{n}}
# $$
# y
#
# $$LI = \bar{x} - EM$$
# $$LS = \bar{x} + EM$$
#
# El error de estimación esta acotado:
# $$
# |{\bar{x}} - \mu| \le z_{1-\alpha/2} \frac{\sigma}{\sqrt{n}}
# $$
#
# Si queremos calcular el tamaño muestral necesario para que el error sea menor o igual a una cantidad  e (e.g.: 0.05), hacemos:
#
# $$
# z_{1-\alpha/2} \frac{\sigma}{\sqrt{n}} \le e \Longleftrightarrow n \ge \frac{z_{1-\alpha/2}^2\sigma^2}{e^2}
# $$

# %% [markdown]
# **Nota:**
# Cuando se cuenta con una muestra grande $(n \ge 30)$, pero la __desviación estándar de la población es desconocida__,  se debe utilizar la desviación estándar de la muestra como un estimador de la desviación estándar poblacional.
#
# $$
# \left(\bar{x} - Z_{1-\alpha/2}\frac{S}{\sqrt{n}};\quad\bar{x} + Z_{1-\alpha/2}\frac{S}{\sqrt{n}}\right)
# $$
# donde
# $$
# S = \hat{S} = \sqrt{\frac{\sum{(x_i - \bar{x})^2}}{n-1}}
# $$

# %% [markdown]
# ### <font color='green'>Actividad 6</font>
# ### IC para muestras grandes
#
# Se extrajo una muestra aleatoria de 172 clientes de la nueva APP de compras "cornerTop", y se les pidió que recordaran su última experiencia de compra para evaluar el servicio recibido en una escala de 1 (muy insatisfecho) a 5 (muy satisfecho). La satisfacción de los clientes recibió una calificación media de 4.38 con una desviación estándar muestral de 0.70.
#
# 1. Calcular un Intervalo de Confianza del 95% para la media poblacional.
# 2. Calcular un Intervalo de Confianza del 99% para la media poblacional.
# 3. Visualice la distribución y el límite.

# %%
# como n >= 30 aplicaremos Z (Distribucion normal estandadarizada)

# Caso NC = 0.95
# primero registrar los datos

n= 172 #numero de clientes
xbar = 4.38 #media muestrañ
S = 0.7 #desviacion estandar muestral

# IC con NC 95%
NC = 0.95
alpha = 1 - NC
alpha_medio = alpha / 2

# Calcular Z con la función de distribución normal acumulada inversa (ppf)
Z = stats.norm.ppf(1 - alpha_medio)
print(f"Z: {Z: 6.4f}")

LI = xbar - Z * (S / np.sqrt(n))
LS = xbar + Z * (S / np.sqrt(n))

print(f'Intervalo de Confianza (IC) al {NC} para media poblacional: {LI:4.2f}, {LS:4.2f}')
# Out:
# Z:  1.9600
# Intervalo de Confianza (IC) al 0.95 para media poblacional: 4.28, 4.48

# %%
# Forma simple con Scipy
IC95 = stats.norm.interval(NC, loc = xbar, scale = S /np.sqrt(n))
print(f'IC al {NC} para media poblacional:  {IC95[0]:4.2f}, {IC95[1]:4.2f}')
# Out:
# IC al 0.9 para media poblacional:  25.57, 25.63

# %%
#Graficando la distribucion normal de poblacion y medias

n = 172
xbar = 4.38
S = 0.7
S_xbar = S / np.sqrt(n)

# proyectar distribución población
poblacion = stats.norm(xbar, S)
x = np.linspace(poblacion.ppf(0.01), poblacion.ppf(0.99), 100)
pdf = poblacion.pdf(x) # función densidad probabilidad

# proyectar distribución medias n=172
medias = stats.norm(xbar, S_xbar)
x_m = np.linspace(medias.ppf(0.01), medias.ppf(0.99), 100)
pdf_m = medias.pdf(x_m) # función densidad probabilidad

plt.figure(figsize=(10, 5)) # tamaño gráfico
# plt.plot(x, pdf,"r", label= 'Población') # poblacion fit
plt.plot(x_m, pdf_m,"b", label = 'Muestras') # medias fit
plt.vlines(ymin=0, ymax=7, x=LI, label = 'Límite Inferior')# LS IC
plt.vlines(ymin=0, ymax=7, x=LS, label = 'Límite Superior')# LS IC
plt.legend()
plt.show()

# Solo para comprobar:
# calcular probabilidad de tomar una muestra y que ésta tenga una media menor al LS del IC
prob_acum_LS = stats.norm(xbar, S_xbar).cdf(LS)
print(f'La probabilidad es: {prob_acum_LS:6.4f}')
# Out:
# La probabilidad es: 0.9750

# %% [markdown]
# <font color='green'>Fin actividad 6</font>

# %% [markdown]
# ### <font color ='green'>Actividad 7</font>
#
# La empresa de transporte DUDU planea importar una flota de nuevos taxis para sus conductores. La decisión depende de si el rendimiento del auto en consideración tiene por lo menos 27.5 MPG (millas por galón). Los 36 autos que prueba la empresa reportaron una media de 25.6 MPG, con una desviación estándar muestral de 3.5 MPG.
#
# 1. A un nivel de confianza del 99% ¿qué aconsejaría a la empresa que hiciera?
#
# Nota:<br>
# 27.5 MPG = 11.69 Km/L<br>
# 25.6 MPG = 10.88 Km/L<br>
# 3.5 MPG = 1.49 Km/L

# %%
# como n >= 30 aplicaremos Z (Distribucion normal estandadarizada)

# Caso NC = 0.99
# primero registrar los datos

n= 36 #numero de autos
xbar = 25.6 #media muestral
S = 3.5 #desviacion estandar muestral

# IC con NC 99%
NC = 0.99

# Calculo de intervalos con Scipy
IC99 = stats.norm.interval(NC, loc = xbar, scale = S /np.sqrt(n))
print(f'IC al {NC} para media poblacional:  {IC99[0]:4.2f}, {IC99[1]:4.2f}')

# proyectar distribución población
poblacion = stats.norm(xbar, S)
x = np.linspace(poblacion.ppf(0.0001), poblacion.ppf(0.9999), 100)
pdf = poblacion.pdf(x) # función densidad probabilidad

# proyectar distribución medias n=172
medias = stats.norm(xbar, S /np.sqrt(n))
x_m = np.linspace(medias.ppf(0.0001), medias.ppf(0.9999), 100)
pdf_m = medias.pdf(x_m) # función densidad probabilidad

LI = IC99[0]
LS = IC99[1]
lim_rendimiento = 27.5

plt.figure(figsize=(10, 5)) # tamaño gráfico
# plt.plot(x, pdf,"r", label= 'Población') # poblacion fit
plt.plot(x_m, pdf_m,"b", label = 'Muestras') # medias fit
plt.vlines(ymin=0, ymax=0.7, x=LI, label = 'Límite Inferior')# LS IC
plt.vlines(ymin=0, ymax=0.7, x=LS, label = 'Límite Superior')# LS IC
plt.vlines(ymin=0, ymax=0.7, x=lim_rendimiento, colors='r', label='Rendimiento minimo', linestyles='--')
plt.legend()
plt.show()

# calcular probabilidad de tener un rendimiento de 27.5
prob_acum_value = stats.norm(xbar, S /np.sqrt(n)).cdf(lim_rendimiento)
print(f'La probabilidad de superar el rendimiento de 27.5 en la distribución es de: {1-prob_acum_value:6.4f} ({(1-prob_acum_value)*100:2.2f}%)')
# Out:
# IC al 0.99 para media poblacional:  24.10, 27.10
# La probabilidad de superar el rendimiento de 27.5 en la distribución es de: 0.0006 (0.06%)

# %% [markdown]
# **_Conclusión:_** Dada la baja probabilidad de superar el rendimiento minimo esperado, no es recomendable la compra del vehiculo.

# %% [markdown]
# <font color='green'>Fin actividad 7</font>

# %% [markdown]
# ### <font color='green'>Actividad 8 Opcional</font>
# Un artículo publicado en el Journal of Heat Transfer (Trans ASME, Ses. C, 96 1974, pag. 59) describe un nuevo método para medir la conductividad térmica del hierro Armco. Al utilizar una temperatura de 100ºF y una potencia de entrada de 550 W, se obtienen las diez mediciones siguientes de conductividad térmica (en BTU/hr-ft-ºF):
# ```Python
# conductividad = (41.6, 41.48, 42.34, 41.95, 41.86, 42.18, 41.72, 42.26, 41.81, 42.04)
# ```
#
# 1. Se desea construir un IC del 95% para conductividad térmica promedio de ese material, se sabe que la desviación estándar es de 0,30 Btu/hr-ft-ºF

# %%
# n < 30, pero se conoce la desv. std poblacional, por tanto aplicar Z

# Datos 10 mediciones
conductividad = (41.6, 41.48, 42.34, 41.95, 41.86, 42.18, 41.72, 42.26, 41.81, 42.04)

# Tu código aquí ...

# %% [markdown]
# <font color='green'>Fin actividad 8</font>

# %% [markdown]
# ### <font color='green'>Actividad 9 opcional</font>
#
# Se desea estimar la velocidad media en una calle con un límite teórico de 80 km/hora.
#
# Con un radar oculto, se observó que la velocidad media de una muestra de 25 autos fue de 88 km/hora. Si la desviación estándar de la velocidad en esta calle es de 6 km/hora:
# 1. Calcule un intervalo de 95 % de confianza para la verdadera velocidad media.
# 2. Visualice la distribución y los límites.

# %%
# Tu código aquí ...

# %% [markdown]
# <font color='green'>Fin actividad 9</font>

# %% [markdown]
# ### Muestras pequeñas
#
# Cuando __no se conoce__ el valor de  $\sigma$ y $n \lt 30$, entonces el I.C. para la media muestral aplicará la __Distribución T de Student__:
#
# $$
# \left(\bar{x} - t_{n-1,\alpha/2} \frac{\hat{S}}{\sqrt{n}}; \quad \bar{x} + t_{n-1,\alpha/2} \frac{\hat{S}}{\sqrt{n}}  \right)
# $$

# %% [markdown]
# Siendo $t_{n-1,\alpha/2}$ el valor de una Distribución t-Student con $(n-1)$ grados de libertad, que deja a la derecha $\alpha/2$ de área (mismo significado que en el caso anterior, pero debemos buscar dicho valor en la densidad $t$ con $(n-1)$ grados de libertad).
#
# $$
# T = \frac{\bar{x} - \mu}{\frac{S}{\sqrt{n}}} \sim t_{n-1}
# $$

# %% [markdown]
# Los grados de libertad de la Distribución T-Student se corresponden con el tamaño de la muestra con la que se calculó $\hat{S}$.
#
# <img src='https://drive.google.com/uc?export=view&id=1hWOWCvymoMYWBnF4PaRycoiqLcNc_NOG' width="400" align="left" style="margin-right: 20px">
# <br>

# %% [markdown]
# __Notas:__
#
# 1. Si la muestra es pequeña, pero se conoce la desviación estándar de la población, el cálculo de IC debe aplicar la Distribución Normal estándar ($Z$).
# 2. En la práctica, si de una población no se conoce la media (y por eso intentamos estimarla), es raro conocer la desviación típica. En estos casos, utilizaremos el segundo método presentado.

# %% [markdown]
# ### <font color='green'>Actividad 10</font>
# Un artículo públicado en el Journal of testing and Evaluation presenta las siguientes 20 mediciones del tiempo de combustión residual (en segundos) de especímenes tratados de ropa de dormir para niños:
#
# ```python
# tiempo = (9.85, 9.93, 9.75, 9.77, 9.67, 9.87, 9.67, 9.94, 9.85, 9.75, 9.83, 9.92, 9.74, 9.99, 9.88, 9.95, 9.95, 9.93, 9.92, 9.89)
# ```
# 1. Se desea encontrar un IC del 95% para el tiempo de combustión residual promedio.

# %%
# n < 30, y se desconoce la desv. std poblacional, por tanto aplicar T (distribucion de Student)

# Datos 20 mediciones
tiempo = [9.85, 9.93, 9.75, 9.77, 9.67, 9.87, 9.67, 9.94, 9.85, 9.75, 9.83, 9.92, 9.74, 9.99, 9.88, 9.95, 9.95, 9.93, 9.92, 9.89]
n = len(tiempo)
xbarra = np.mean(tiempo)
S = np.std(tiempo, ddof=1)

print(f'La media muestral es de {xbarra:2.2f}')
print(f'La desviación estandar muestral es de {S:2.2f}')

NC = 0.95

# hay que cambiar norm por t-student
IC95 = stats.t.interval(NC, loc = xbarra, scale = S /np.sqrt(n), df = n-1)
print(f'IC al {NC} para media poblacional:  {IC95[0]:4.2f}, {IC95[1]:4.2f}')
# Out:
# La media muestral es de 9.85
# La desviación estandar muestral es de 0.10
# IC al 0.95 para media poblacional:  9.81, 9.90

# %% [markdown]
# <font color='green'>Fin actividad 10</font>

# %% [markdown]
# ##Intervalo de Confianza para Proporción Poblacional

# %% [markdown]
# Un estimador de intervalo de confianza  de la proporción en la población ($p$), es un intervalo, calculado a partir de los datos de la muestra, en el cual nosotros “confiamos” se encuentra la proporción de la población.
#
# Una proporción muestral $\hat{p}$ es un estimador puntual de la proporción $p$ de la población. Entonces:
# $$
# \hat{p} \sim N\left(p; \quad \sqrt{\frac{p(1-p)}{n}} \right)
# $$

# %% [markdown]
# __Pasos:__
#
# 1. Fijar el nivel de confianza, $(1-\alpha);\quad 0 \lt \alpha \lt 1$.
# 2. Si $n$ es grande $(n \gt 30)$, $\hat{p}$ es un estimador de la proporción $p$ de la población:
#
# $$
# \hat{p} = \frac{x_1 + x_2 + \dots + x_i}{n}
# $$
#
# Donde cada $x_i$ toma el valor 1, si presenta la característica de la población y 0 si no la tiene.

# %% [markdown]
# 3.   Selección del Estadístico Pivote ($Z$) para la estimar la proporción muestral:
#
# $$Z = \frac{\hat{p} - p}{\sqrt{\frac{p\:(1-p)}{n}}} \sim N(0,1)$$

# %% [markdown]
# 4.   Plantear el Intervalo de confianza para 𝒑 con nivel de confianza $(1-\alpha)$
#
# $$
# IC_{1-\alpha}(p): \underbrace{ \bigg(\hat{p}-Z_{1-\alpha/2}\underbrace{{\sqrt{\frac{p\:(1-p)}{n}}}}_{EM}}_{LI};\quad \underbrace{\hat{p}+Z_{1-\alpha/2}\underbrace{{\sqrt{\frac{p\:(1-p)}{n}}}}_{EM} \bigg)}_{LS}
# $$
# donde:<br>
# $LI$: Límite inferior<br>
# $LS$: Límite superior<br>
# $EM$: Error muestral<br>

# %% [markdown]
# **Consideraciones:**
# En la práctica, no se puede calcular el intervalo porque la desviación estándar depende del valor desconocido $p$. Para resolver dicho problema se presenta la siguiente alternativa:
#
# Sustituir $p$ por su estimador $\hat{p}$. El intervalo resultante es:
#
# $$
# IC_{1-\alpha}(p):  \bigg(\hat{p}-Z_{1-\alpha/2}\sqrt{\frac{\hat{p}\:(1-\hat{p})}{n}};\quad \hat{p}+Z_{1-\alpha/2}\sqrt{\frac{\hat{p}\:(1-\hat{p})}{n}} \bigg)
# $$

# %% [markdown]
# <img src='https://drive.google.com/uc?export=view&id=1fzZXao1gDm8r41ZoX8xZm_5wIiUaA9rx' width="500" align="left" style="margin-right: 20px">
# <br>

# %% [markdown]
# ### Ejemplo de IC en proporciones
# Se selecciona aleatoriamente una muestra de 600 personas en una ciudad y se les pregunta si consideran que el tráfico en la misma es aceptablemente fluido. Responden afirmativamente 250 personas. ¿Cuál es el intervalo de confianza de la proporción de ciudadanos de esa ciudad que consideran aceptable la fluidez del tráfico, con un nivel de confianza del 90 % ?

# %%
# n >= 30,  n*p y n*(1-p) >= 5, aplicar Dist. Normal Std (Z)
# Datos
n = 600
p = 250 / n # prop. muestral 'si es fluido'
S = np.sqrt(p * (1 - p)) # desv std de la muestra

NC = 0.90
alpha = 1 - NC
alpha_medio = alpha / 2

# Calcular Z con la función de distribución normal acumulada inversa (ppf)
Z = stats.norm.ppf(1 - alpha_medio)#2 colas IC
print(f'Z: {Z:4.2f}')

LI = p - Z *(S / np.sqrt(n))
LS = p + Z *(S / np.sqrt(n))

print(f'Intervalo de Confianza (IC) al {NC} para media poblacional: {LI:4.2f}, {LS:4.2f}')
# Out:
# Z: 1.64
# Intervalo de Confianza (IC) al 0.9 para media poblacional: 0.38, 0.45

# %%
#Forma simple con Scipy
IC90 = stats.norm.interval(NC, loc = p, scale = S /np.sqrt(n))
print(f'IC al {NC} para media poblacional:  {IC90[0]:4.2f}, {IC90[1]:4.2f}')
# Out:
# IC al 0.9 para media poblacional:  0.38, 0.45

# %% [markdown]
# ### <font color='green'>Actividad 11</font>
# Una de las últimas encuestas sobre los candidatos a las elecciones de diciembre del 2005, dice que la candidata Marta Mujica obtiene un 49% de las preferencias.
#
# La ficha técnica de la muestra, nos indica lo siguiente:
# * n = 830
# * p = 0.49
# * Nivel de confianza = 0.95
# * error muestral = 0.034
#
# Construya un intervalo de 95% de confianza para la estimación de la encuesta. Interprete. ¿Corresponde el error muestral de la ficha técnica al calculado por usted?

# %%
# Tu código aquí ...

# n >= 30,  n*p y n*(1-p) >= 5, aplicar Dist. Normal Std (Z)
# Datos
n = 830
p = 0.49
S = np.sqrt(p * (1 - p)) # desv std de la muestra

NC = 0.95
alpha = 1 - NC
alpha_medio = alpha / 2

#Forma simple con Scipy
IC95 = stats.norm.interval(NC, loc = p, scale = S /np.sqrt(n))
print(f'IC al {NC} para media poblacional:  {IC95[0]:4.2f}, {IC95[1]:4.2f}')

EM = (S / np.sqrt(n))
print(f'El error muestral es {EM:4.4f}')
# print(EM*2)
# Out:
# IC al 0.95 para media poblacional:  0.46, 0.52
# El error muestral es 0.0174

# %% [markdown]
# **_Conclusion:_** El error muestral (considerando el limite superior e inferior) es de 0.0174*2 = 0.0347, es decir, coincide con el presentado por el informe del estudio. Sin embargo, es importante mencionar que el error muestral por definición corresponde solo a una mitad del ancho del intervalo, es decir, el valor es de 0.0174.

# %% [markdown]
# <font color='green'>Fin actividad 11</font>

# %% [markdown]
# ## <font color='blue'>Control del ancho de un intervalo</font>
# Para disminuir el error muestral o mejorar la precisión se debe considerar:
# * A mayor tamaño de la muestra, menor es el Margen de Error.
# * Cuanto menor es la desviación estandar $\sigma$, menor es el Margen de Error.
#
# Qué elementos no contribuyen a mejorar la estimación:
# * Cuanto mayor es el nivel de confianza $(1-\alpha)$, mayor es el Margen de Error.
# * A menor tamaño de la muestra, mayor es el Margen de Error.
# * A mayor heterogeneidad de la población, mayor es el Margen de Error.

# %% [markdown]
# ## <font color='blue'>Determinación del tamaño apropiado de la muestra</fonrt>
#
# ### Medias
#
# ¿Qué se necesita para determinar el __tamaño de una muestra__ para un promedio?
#
# * Establecer el __Margen Error__ deseado.
# * Establecer el __Nivel de Confianza__  o __Riesgo__.
# * Magnitud de la dispersión o grado de heterogeneidad de la variable.
#
# $$
# z_{1-\alpha/2} \frac{\sigma}{\sqrt{n}} \le EM \Longleftrightarrow n \ge \left(z_{1-\alpha/2}\frac{\sigma}{EM}\right)^2
# $$

# %% [markdown]
# ### Ejemplo para medias
# Una tienda local vende bolsas de plástico para basura y ha recibido unas cuantas quejas con respecto a la resistencia de tales bolsas. Parece ser que las bolsas que se venden en la tienda son menos resistentes que las que vende su competidor y, en consecuencia, se rompen más a menudo. El gerente encargado de adquisición, está interesado en determinar el peso máximo promedio que puede resistir una de las bolsas para basura sin que se rompa. Si la desviación estándar del peso límite que puede aguantar una bolsa es de 1.2 Kg, determine el número de bolsas que deben ser probadas con el fin de que el Gerente tenga una certeza de 95% de que el peso límite promedio está dentro de 0.5 Kg, del promedio real.

# %%
# Datos
Sigma = 1.2 # desv std poblacional conocida
# (LS - LI) = ancho del intervalo = 2 * error muestral
error_muestral = 0.5
NC = 0.95
alpha = 1 - NC
alpha_medio = alpha / 2
Z = stats.norm.ppf(1 - alpha_medio) #2 colas
print(f'Z: {Z:6.4f}')

# n= ?
n = ((Z * Sigma) / error_muestral)**2
print('El tamaño de la muestra debe ser > ', round(n))
# Out:
# Z: 1.9600
# El tamaño de la muestra debe ser >  22

# %% [markdown]
# ###Proporción
# Al igual que en el caso de la media, para obtener el tamaño muestral que cumpla el requirimiento del investigador, se obtiene despejando $n$ de la expresión:
#
# $$
# EM = Z_{1-\alpha/2}\sqrt{\frac{\hat{p}\:(1-\hat{p})}{n}} \Longrightarrow	n = \frac{Z_{1-\alpha/2}^2 \hat{p}\:(1-\hat{p})}{EM^2}
# $$

# %% [markdown]
# ### Ejemplo para proporiones
# Para estimar la proporción de familias de una determinada ciudad que poseen microondas, se quiere utilizar una muestra aleatoria de medida $n$.
#
# Calcula el valor mínimo de $n$ para garantizar que, a un nivel de confianza del 95%, el error en la estimación sea menor que 0,05. Como se desconoce la proporción, se ha de tomar el caso más desfavorable, que será 0,5.

# %%
# Datos
P = 0.5 # se desconoce Prop poblacional, se utiliza varianza maxima
Sigma = np.sqrt(P * (1 - P)) # desv std poblacional
# (LS - LI) = ancho del intervalo = 2*error muestral
error_muestral = 0.05
NC = 0.95
alpha = 1 - NC
alpha_medio = alpha / 2
Z = stats.norm.ppf(1 - alpha_medio) #2 colas
print(f'Z: {Z:6.4f}')

# n= ?
n = ((Z * Sigma) / error_muestral)**2
print('El tamaño de la muestra debe ser > ', round(n))
# Out:
# Z: 1.9600
# El tamaño de la muestra debe ser >  384

# %% [markdown]
# ### <font color='green'>Actividad 12</font>
# Para estimar la proporción de las viviendas de una determinada ciudad que tienen aire acondicionado se quiere utilizar una muestra de tamaño $n$. Calcule el valor mínimo de $n$ para que, con un nivel de confianza del 97%, el error en la estimación sea más pequeño que 0,05.
#
# Como se desconoce la proporción, se debe tomar el caso más desfavorable, que será 0,5.

# %%
# Tu código aquí ...

# Datos
P = 0.5 # se desconoce Prop poblacional, se utiliza varianza maxima
Sigma = np.sqrt(P * (1 - P)) # desv std poblacional
# (LS - LI) = ancho del intervalo = 2*error muestral
error_muestral = 0.05
NC = 0.97
alpha = 1 - NC
alpha_medio = alpha / 2
Z = stats.norm.ppf(1 - alpha_medio) #2 colas
print(f'Z: {Z:6.4f}')

# n= ?
n = ((Z * Sigma) / error_muestral)**2
print('El tamaño de la muestra debe ser > ', round(n))
# Out:
# Z: 2.1701
# El tamaño de la muestra debe ser >  471

# %% [markdown]
# <font color='green'>Fin actividad 12</font>
